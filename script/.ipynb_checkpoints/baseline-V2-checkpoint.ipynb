# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import lightgbm

from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %%
rep_cols = {'ID':'ID', 
 '板温':'board_t', 
 '现场温度':'env_t', 
 '光照强度':'light_strength', 
 '转换效率':'efficiency', 
 '转换效率A':'efficiency_A', 
 '转换效率B':'efficiency_B', 
 '转换效率C':'efficiency_C', 
 '电压A':'V_A',
 '电压B':'V_B', 
 '电压C':'V_C', 
 '电流A':'I_A', 
 '电流B':'I_B', 
 '电流C':'I_C', 
 '功率A':'P_A', 
 '功率B':'P_B', 
 '功率C':'P_C', 
 '平均功率':'P_avg', 
 '风速':'wind_speed',
 '风向':'wind_direction', 
 '发电量':'y'
}

# %%
def my_val(preds, train_data):
    label = train_data.get_label()
    return 'score', 1/(1+np.sqrt(mean_squared_error(preds, label))), True

# %%
def my_obj(preds, train_data):
    labels = train_deata.get_label()

# %%
train = pd.read_csv('../data/public.train.csv')
test = pd.read_csv('../data/public.test.csv')

train_len = train.shape[0]

df = pd.concat([train, test])

# %%
df.rename(index=str, columns=rep_cols, inplace=True)

# %%
df.head()
# Out:
#    ID  light_strength      P_A     P_B      P_C         y    P_avg  board_t  \
# 0  10              34   976.86  155.98  1087.50  1.437752   740.11   -19.14
# 1  11              30  1128.40  172.08  1132.56  1.692575   811.01   -18.73
# 2  12              41  1279.25  166.06  1310.40  1.975787   918.57   -17.54
# 3  14              53  1474.60  225.37  1517.34  2.370656  1072.44   -15.43
# 4  15              65  1548.51  233.28  1674.40  2.532091  1152.06   -14.60
#
#    env_t  V_A     ...      V_C   I_A   I_B   I_C  efficiency  efficiency_A  \
# 0  -17.4  729     ...      725  1.34  0.22  1.50       80.55        106.32
# 1  -17.3  728     ...      726  1.55  0.24  1.56       99.90        139.00
# 2  -17.0  731     ...      720  1.75  0.23  1.82       82.48        114.86
# 3  -16.6  730     ...      726  2.02  0.31  2.09       73.98        101.72
# 4  -16.3  727     ...      728  2.13  0.32  2.30       64.62         86.86
#
#    efficiency_B  efficiency_C  wind_direction  wind_speed
# 0         16.98        118.36             272         0.6
# 1         21.20        139.51             275         0.8
# 2         14.91        117.66             283         1.1
# 3         15.55        104.67             280         0.9
# 4         13.09         93.92             280         1.1
#
# [5 rows x 21 columns]

# %%
#异常值处理
# 改用均值
cols = [c for c in df.columns.tolist() if c!='y' and c!='ID']
for c in cols:
    df[c+'_is_out_of_upper'] = (df[c]>df[c].quantile(0.99)).astype(np.int32)
    df[c+'_is_out_of_lower'] = (df[c]<df[c].quantile(0.01)).astype(np.int32)
    df[(df[c]>df[c].quantile(0.99))|(df[c]<df[c].quantile(0.01))][c]=np.nan
    df[c].fillna(df[c].median(),inplace=True)
# Out:
# /Users/wyh/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
target = ['P_A','P_avg','I_A','P_C','I_C','P_B','I_B']
target_plus = [c+'_is_out_of_upper' for c in target]+[c+'_is_out_of_lower' for c in target]+target
for c in target:
    df['log_'+c] = np.log1p(df[c])

# %%
# 估算功率
df['predict_p_1'] = df['P_A']+df['P_B']+df['P_C']
df['predict_p_2'] = (df['P_A']*df['efficiency_A'] \
                   +df['P_B']*df['efficiency_B'] \
                   +df['P_C']*df['efficiency_C'])/36000

# %%
# 第一阶，用其他值预测某些特征

params_layer1 = {
    'boosting_type': 'gbdt',
    'objective': 'regression_l1',
    'metric': 'mae',
    'num_leaves': 48,
    'learning_rate': 0.2,
#     'feature_fraction': 0.7,
    'bagging_fraction': 0.8,
    'bagging_freq': 1,
    'verbose': 0
}
kf_layer1 = KFold(3, shuffle=True, random_state=1991)

layer1_result = df[['ID']]

for t in target:
    print('Now, we are processing',t)
    # 特征中去掉t
    predictor_t = [c for c in target_plus if c not in['ID','y',t,t+'_is_out_of_upper',t+'_is_out_of_lower']]
    
    # 初始化结果
    val_preds = np.zeros(df.shape[0])
    
    for n_fold, (tra_idx, val_idx) in enumerate(kf_layer1.split(df)):
        tra = df.iloc[tra_idx]
        # 删掉有问题的数据
        tra.drop(tra[(tra[t+'_is_out_of_upper']==1)|(tra[t+'_is_out_of_lower']==1)].index, inplace=True)
        
        val = df.iloc[val_idx]
        # 删掉有问题的数据
        val_c = val.drop(val[(val[t+'_is_out_of_upper']==1)|(val[t+'_is_out_of_lower']==1)].index)

        train_set = lightgbm.Dataset(
            tra[predictor_t],
            tra[t]
        )

        validation_set = lightgbm.Dataset(
            val_c[predictor_t],
            val_c[t]
        )

        model = lightgbm.train(params_layer1, train_set, 
                               num_boost_round=8000,
                              valid_sets= [validation_set],
                              valid_names=['valid'],
                              early_stopping_rounds=20,
                              verbose_eval=1000)

        val_preds[val_idx] = model.predict(val[predictor_t])
        
    # 将结果保存起来
    layer1_result['predicted_'+t] = val_preds
# Out:
# Now, we are processing P_A
# Training until validation scores don't improve for 20 rounds.
# /Users/wyh/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Early stopping, best iteration is:
# [751]	valid's l1: 19.7346
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 20.6882
# [2000]	valid's l1: 20.1342
# Early stopping, best iteration is:
# [2223]	valid's l1: 20.0669
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 20.9161
# Early stopping, best iteration is:
# [1308]	valid's l1: 20.6166
# /Users/wyh/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Now, we are processing P_avg
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 9.98123
# Early stopping, best iteration is:
# [1256]	valid's l1: 9.88543
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 9.93393
# Early stopping, best iteration is:
# [1572]	valid's l1: 9.71995
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 9.6463
# Early stopping, best iteration is:
# [1430]	valid's l1: 9.50549
# Now, we are processing I_A
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 0.03622
# Early stopping, best iteration is:
# [1116]	valid's l1: 0.0360427
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 0.0372562
# Early stopping, best iteration is:
# [988]	valid's l1: 0.0372478
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 0.0355553
# Early stopping, best iteration is:
# [1038]	valid's l1: 0.035478
# Now, we are processing P_C
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 20.9856
# Early stopping, best iteration is:
# [1948]	valid's l1: 20.4718
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 20.2846
# Early stopping, best iteration is:
# [1304]	valid's l1: 20.0961
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 18.9535
# Early stopping, best iteration is:
# [1451]	valid's l1: 18.6187
# Now, we are processing I_C
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 0.0351321
# Early stopping, best iteration is:
# [1098]	valid's l1: 0.0350017
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 0.0353729
# Early stopping, best iteration is:
# [1217]	valid's l1: 0.0351105
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 0.0352782
# Early stopping, best iteration is:
# [1525]	valid's l1: 0.0346918
# Now, we are processing P_B
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 21.4159
# [2000]	valid's l1: 20.8265
# Early stopping, best iteration is:
# [2154]	valid's l1: 20.7884
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 20.6594
# Early stopping, best iteration is:
# [1137]	valid's l1: 20.5522
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 22.0995
# [2000]	valid's l1: 21.5559
# [3000]	valid's l1: 21.3138
# [4000]	valid's l1: 21.1187
# Early stopping, best iteration is:
# [4071]	valid's l1: 21.1092
# Now, we are processing I_B
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 0.0361006
# [2000]	valid's l1: 0.0349518
# Early stopping, best iteration is:
# [2506]	valid's l1: 0.0346315
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 0.0346798
# Early stopping, best iteration is:
# [1423]	valid's l1: 0.0341732
# Training until validation scores don't improve for 20 rounds.
# [1000]	valid's l1: 0.0353894
# Early stopping, best iteration is:
# [1755]	valid's l1: 0.0345007

# %%
layer1_result.head()
# Out:
#    ID  predicted_P_A  predicted_P_avg  predicted_I_A  predicted_P_C  \
# 0  10     852.802597       756.483336       1.462350    1097.639430
# 1  11    1115.429979       809.889903       1.547411    1152.026598
# 2  12    1285.242300       928.907016       1.759097    1329.374632
# 3  14    1489.419024      1091.271283       2.056612    1498.716542
# 4  15    1511.216897      1117.096194       2.058041    1658.668627
#
#    predicted_I_C  predicted_P_B  predicted_I_B
# 0       1.423265     157.043170       0.219164
# 1       1.550395     163.939634       0.225199
# 2       1.792227     162.750528       0.244601
# 3       2.113968     214.498214       0.313826
# 4       2.338914     240.708355       0.304332

# %%
layer1_result.to_pickle('../feature/predicted_value-2.pkl')

# %%
layer1_result = pd.read_pickle('../feature/predicted_value.pkl')

# %%
df = df.merge(layer1_result, on='ID', how='left')

# %%
for t in target:
    df['diff_'+t] = df[t]-df['predicted_'+t]

# %%
train = df.iloc[0:train_len]
test = df.iloc[train_len:]

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression_l2',
    'metric': 'mse',
    'num_leaves': 31,
    'learning_rate': 0.08,
    'feature_fraction': 0.6,
    'bagging_fraction': 0.8,
    'bagging_freq': 1,
    'verbose': 0
}

# %%
predictor = [c for c in train.columns.tolist() if c not in['ID','y']]

# %%
test_predicts = []
val_preds = []

# log_test_predicts = []
# log_val_predicts = []
for idx, seed in enumerate([1,2,3,4,5]):
    kf = KFold(5, shuffle=True, random_state=seed)
    
    val_preds.append(np.zeros(train.shape[0]))
    for n_fold, (tra_idx, val_idx) in enumerate(kf.split(train)):
        tra = train.iloc[tra_idx]
        val = train.iloc[val_idx]

        train_set = lightgbm.Dataset(
            tra[predictor],
            tra['y']
        )

        validation_set = lightgbm.Dataset(
            val[predictor],
            val['y']
        )

        model = lightgbm.train(params, train_set, num_boost_round=5000,
                              valid_sets= [validation_set],
                              valid_names=['valid'],
                              early_stopping_rounds=100,
                               feval=my_val,
                              verbose_eval=500)

        val_preds[idx][val_idx] = model.predict(val[predictor])
        test_predicts.append(model.predict(test[predictor]))
        
#         train_set = lightgbm.Dataset(
#             tra[predictor],
#             np.log1p(tra['y'])
#         )

#         validation_set = lightgbm.Dataset(
#             val[predictor],
#             np.log1p(val['y'])
#         )

#         model = lightgbm.train(params, train_set, num_boost_round=5000,
#                               valid_sets= [validation_set],
#                               valid_names=['valid'],
#                               early_stopping_rounds=100,
#                                feval=my_val,
#                               verbose_eval=500)

#         val_preds[idx][val_idx] = np.expm1(model.predict(val[predictor]))
#         test_predicts.append(np.expm1(model.predict(test[predictor])))
# Out:
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0595163	valid's score: 0.803885
# [1000]	valid's l2: 0.0584562	valid's score: 0.805297
# Early stopping, best iteration is:
# [966]	valid's l2: 0.0584115	valid's score: 0.805357
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.00232145	valid's score: 0.954033
# [1000]	valid's l2: 0.00228149	valid's score: 0.954413
# Early stopping, best iteration is:
# [1033]	valid's l2: 0.00227847	valid's score: 0.954441
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0243566	valid's score: 0.865003
# [1000]	valid's l2: 0.0207628	valid's score: 0.874055
# [1500]	valid's l2: 0.0195856	valid's score: 0.877233
# [2000]	valid's l2: 0.0192078	valid's score: 0.878277
# [2500]	valid's l2: 0.0191046	valid's score: 0.878565
# Early stopping, best iteration is:
# [2585]	valid's l2: 0.019071	valid's score: 0.878659
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0010818	valid's score: 0.968157
# [1000]	valid's l2: 0.000793642	valid's score: 0.9726
# [1500]	valid's l2: 0.000722407	valid's score: 0.973826
# [2000]	valid's l2: 0.000698708	valid's score: 0.974248
# [2500]	valid's l2: 0.000689549	valid's score: 0.974413
# [3000]	valid's l2: 0.00068529	valid's score: 0.97449
# Early stopping, best iteration is:
# [2945]	valid's l2: 0.000684793	valid's score: 0.974499
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [267]	valid's l2: 0.0139887	valid's score: 0.894235
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [163]	valid's l2: 0.000649068	valid's score: 0.975156
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0569258	valid's score: 0.807369
# [1000]	valid's l2: 0.0551413	valid's score: 0.809833
# [1500]	valid's l2: 0.0541139	valid's score: 0.811277
# [2000]	valid's l2: 0.0534139	valid's score: 0.812272
# [2500]	valid's l2: 0.0531604	valid's score: 0.812635
# Early stopping, best iteration is:
# [2521]	valid's l2: 0.053155	valid's score: 0.812642
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0026458	valid's score: 0.951079
# [1000]	valid's l2: 0.00255411	valid's score: 0.951893
# [1500]	valid's l2: 0.0024998	valid's score: 0.952383
# [2000]	valid's l2: 0.00246995	valid's score: 0.952654
# [2500]	valid's l2: 0.00246151	valid's score: 0.952732
# [3000]	valid's l2: 0.00245605	valid's score: 0.952782
# Early stopping, best iteration is:
# [3100]	valid's l2: 0.00245585	valid's score: 0.952783
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0194054	valid's score: 0.877729
# Early stopping, best iteration is:
# [737]	valid's l2: 0.0188189	valid's score: 0.879367
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.000624357	valid's score: 0.975622
# Early stopping, best iteration is:
# [752]	valid's l2: 0.000608708	valid's score: 0.975922
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0679047	valid's score: 0.793282
# [1000]	valid's l2: 0.0666141	valid's score: 0.794851
# [1500]	valid's l2: 0.0657821	valid's score: 0.795874
# [2000]	valid's l2: 0.0653889	valid's score: 0.796361
# [2500]	valid's l2: 0.0651226	valid's score: 0.796691
# [3000]	valid's l2: 0.065052	valid's score: 0.796779
# Early stopping, best iteration is:
# [2916]	valid's l2: 0.0650392	valid's score: 0.796795
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.00318431	valid's score: 0.946585
# Early stopping, best iteration is:
# [802]	valid's l2: 0.00312844	valid's score: 0.94703
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0167884	valid's score: 0.885293
# [1000]	valid's l2: 0.0150695	valid's score: 0.890664
# [1500]	valid's l2: 0.0146469	valid's score: 0.892041
# Early stopping, best iteration is:
# [1712]	valid's l2: 0.0145741	valid's score: 0.892281
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.000789698	valid's score: 0.972667
# [1000]	valid's l2: 0.000730123	valid's score: 0.97369
# [1500]	valid's l2: 0.000715712	valid's score: 0.973944
# Early stopping, best iteration is:
# [1699]	valid's l2: 0.000713721	valid's score: 0.97398
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0242738	valid's score: 0.865201
# Early stopping, best iteration is:
# [435]	valid's l2: 0.0241653	valid's score: 0.865462
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [229]	valid's l2: 0.000861263	valid's score: 0.971489
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.044691	valid's score: 0.82549
# [1000]	valid's l2: 0.042617	valid's score: 0.828886
# [1500]	valid's l2: 0.0416179	valid's score: 0.830562
# [2000]	valid's l2: 0.0411765	valid's score: 0.831311
# [2500]	valid's l2: 0.0410757	valid's score: 0.831482
# Early stopping, best iteration is:
# [2726]	valid's l2: 0.0410616	valid's score: 0.831506
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [70]	valid's l2: 0.00245047	valid's score: 0.952833
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0175233	valid's score: 0.883099
# [1000]	valid's l2: 0.016035	valid's score: 0.887603
# [1500]	valid's l2: 0.0154905	valid's score: 0.889315
# [2000]	valid's l2: 0.0153901	valid's score: 0.889635
# Early stopping, best iteration is:
# [2242]	valid's l2: 0.0153164	valid's score: 0.88987
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.000582971	valid's score: 0.976424
# [1000]	valid's l2: 0.000488192	valid's score: 0.978383
# [1500]	valid's l2: 0.000473196	valid's score: 0.97871
# Early stopping, best iteration is:
# [1416]	valid's l2: 0.000472261	valid's score: 0.978731
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.04117	valid's score: 0.831322
# Early stopping, best iteration is:
# [835]	valid's l2: 0.0394003	valid's score: 0.83438
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.00243936	valid's score: 0.952935
# [1000]	valid's l2: 0.00233387	valid's score: 0.953916
# Early stopping, best iteration is:
# [904]	valid's l2: 0.00233092	valid's score: 0.953944
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0585286	valid's score: 0.8052
# [1000]	valid's l2: 0.0583738	valid's score: 0.805408
# Early stopping, best iteration is:
# [937]	valid's l2: 0.0582843	valid's score: 0.805528
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [209]	valid's l2: 0.00244222	valid's score: 0.952908
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.012991	valid's score: 0.897684
# [1000]	valid's l2: 0.0123457	valid's score: 0.9
# Early stopping, best iteration is:
# [1000]	valid's l2: 0.0123457	valid's score: 0.9
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.000534474	valid's score: 0.977404
# Early stopping, best iteration is:
# [714]	valid's l2: 0.000521868	valid's score: 0.977666
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [347]	valid's l2: 0.0118106	valid's score: 0.901976
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [298]	valid's l2: 0.000395195	valid's score: 0.980508
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0350056	valid's score: 0.842391
# [1000]	valid's l2: 0.0318552	valid's score: 0.848551
# [1500]	valid's l2: 0.031228	valid's score: 0.849824
# Early stopping, best iteration is:
# [1584]	valid's l2: 0.0311252	valid's score: 0.850034
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.00129562	valid's score: 0.965256
# [1000]	valid's l2: 0.00110388	valid's score: 0.967844
# [1500]	valid's l2: 0.00106632	valid's score: 0.968378
# Early stopping, best iteration is:
# [1656]	valid's l2: 0.00106298	valid's score: 0.968426
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0223754	valid's score: 0.86988
# Early stopping, best iteration is:
# [419]	valid's l2: 0.0218886	valid's score: 0.87112
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [139]	valid's l2: 0.00145661	valid's score: 0.963237
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [256]	valid's l2: 0.0557843	valid's score: 0.808939
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [303]	valid's l2: 0.0019321	valid's score: 0.957895
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0412893	valid's score: 0.831119
# [1000]	valid's l2: 0.0394188	valid's score: 0.834347
# [1500]	valid's l2: 0.0390619	valid's score: 0.834975
# Early stopping, best iteration is:
# [1492]	valid's l2: 0.0390357	valid's score: 0.835021
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.00201664	valid's score: 0.957023
# [1000]	valid's l2: 0.00191546	valid's score: 0.958069
# Early stopping, best iteration is:
# [1291]	valid's l2: 0.00189878	valid's score: 0.958244
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0367748	valid's score: 0.83909
# [1000]	valid's l2: 0.0339503	valid's score: 0.844412
# [1500]	valid's l2: 0.0330573	valid's score: 0.846155
# [2000]	valid's l2: 0.0326429	valid's score: 0.846974
# Early stopping, best iteration is:
# [2228]	valid's l2: 0.0325521	valid's score: 0.847155
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.00194285	valid's score: 0.957783
# Early stopping, best iteration is:
# [854]	valid's l2: 0.00182984	valid's score: 0.958978
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0230576	valid's score: 0.868171
# Early stopping, best iteration is:
# [622]	valid's l2: 0.0227697	valid's score: 0.868888
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.000861584	valid's score: 0.971484
# [1000]	valid's l2: 0.000843741	valid's score: 0.971773
# Early stopping, best iteration is:
# [1015]	valid's l2: 0.000841956	valid's score: 0.971802
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0162724	valid's score: 0.886868
# Early stopping, best iteration is:
# [492]	valid's l2: 0.0162606	valid's score: 0.886904
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.000675494	valid's score: 0.974668
# Early stopping, best iteration is:
# [499]	valid's l2: 0.000674863	valid's score: 0.97468
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.108633	valid's score: 0.752109
# [1000]	valid's l2: 0.100832	valid's score: 0.75899
# [1500]	valid's l2: 0.0967577	valid's score: 0.762742
# [2000]	valid's l2: 0.0951079	valid's score: 0.764295
# [2500]	valid's l2: 0.094273	valid's score: 0.765088
# [3000]	valid's l2: 0.0938517	valid's score: 0.76549
# [3500]	valid's l2: 0.0937166	valid's score: 0.76562
# [4000]	valid's l2: 0.0936294	valid's score: 0.765703
# Early stopping, best iteration is:
# [4388]	valid's l2: 0.0935966	valid's score: 0.765735
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.00574162	valid's score: 0.929564
# [1000]	valid's l2: 0.00520225	valid's score: 0.932726
# [1500]	valid's l2: 0.00494306	valid's score: 0.934311
# [2000]	valid's l2: 0.00483306	valid's score: 0.934999
# [2500]	valid's l2: 0.00478599	valid's score: 0.935295
# [3000]	valid's l2: 0.00475792	valid's score: 0.935473
# [3500]	valid's l2: 0.00474497	valid's score: 0.935555
# [4000]	valid's l2: 0.00473912	valid's score: 0.935593
# Early stopping, best iteration is:
# [4312]	valid's l2: 0.00473727	valid's score: 0.935604
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [174]	valid's l2: 0.0223399	valid's score: 0.86997
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [85]	valid's l2: 0.00148231	valid's score: 0.962927
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [250]	valid's l2: 0.0194763	valid's score: 0.877533
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [250]	valid's l2: 0.000802926	valid's score: 0.972445
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [158]	valid's l2: 0.0242382	valid's score: 0.865287
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [158]	valid's l2: 0.000756437	valid's score: 0.973233

# %%
print('local cv:',1/(1+np.sqrt(mean_squared_error(train['y'],np.mean(val_preds,axis=0)))))
# Out:
# local cv: 0.84471036717

# %%
pd.Series(model.feature_importance(importance_type='gain'),
          index=model.feature_name()).sort_values(ascending=False).head(10)
# Out:
# P_A            149565.022537
# log_P_A        119033.936902
# predict_p_1     69059.933031
# log_I_A         35469.712810
# P_C             33481.684715
# log_P_avg        9959.648253
# I_A              9768.608915
# P_avg            7456.004372
# I_C              7110.851514
# P_B              3886.261329
# dtype: float64

# %%
test['ans'] = np.mean(test_predicts, axis=0)
# Out:
# /Users/wyh/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test[['ID','ans']].to_csv('../result/0729-8523-bagging.csv',header=False, index=False)
