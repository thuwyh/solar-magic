# %% [markdown]
# # 1.问题分析

# %% [markdown]
# ## 1.1.问题类别

# %% [raw]
# 一元回归问题.
# 训练集样本9000条(包括82条重复样本)
# 测试集样本8409条
# 原始特征19个
#
# 预测量为样本对应的发电量
# score = 1/(1+RMSE)

# %% [markdown]
# ## 1.2.特征分析

# %% [raw]
# 时间戳
# ID：当前记录条数；
#
# 测量物理量(连续)
# 板温：光伏电池板背测温度；
# 现场温度：光伏电站现场温度；
# 转换效率：为计算得到的平均转换效率；
# 电压A：为数据采集点A处汇流箱电压值；
# 电压B：为数据采集点B处汇流箱电压值；
# 电压C：为数据采集点C处汇流箱电压值；
# 电流A：为采集点A处汇流箱电流值；
# 电流B：为采集点B处汇流箱电流值；
# 电流C：为采集点C处汇流箱电流值；
# 风速：为光伏电厂现场风速测量值；
# 风向：为光伏电厂现场风的来向；
#
# 计算物理量
# 转换效率A：数据采集点A处的光伏板转换效率；
# 转换效率B：数据采集点B处的光伏板转换效率；
# 转换效率C：数据采集点C处的光伏板转换效率；
# 功率A：为采集点A处的功率Pa，P=UI；
# 功率B：为采集点B处的功率Pb，P=UI；
# 功率C：为采集点C处的功率Pc，P=UI；
# 平均功率：为A、B、C三点功率的平均值：(Pa+Pb+Pc)/3

# %% [markdown]
# ## 1.3.数据挖掘

# %% [raw]
# 详见 0803_数据挖掘.ipynb

# %% [markdown]
# # 2.建立基线

# %% [markdown]
# ## 2.1.准备工具包

# %%
import numpy as np
import pandas as pd
 
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.externals import joblib 
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.decomposition import PCA
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import KFold
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import xgboost as xgb
from lightgbm import LGBMRegressor
import math


from sklearn.model_selection import ShuffleSplit

from sklearn.model_selection import StratifiedKFold


# %matplotlib inline
# Out:
# C:\Users\Alex\Anaconda3\envs\python36\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# C:\Users\Alex\Anaconda3\envs\python36\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## 2.2.数据准备(不进行清洗)

# %%
train_raw = pd.read_csv('../data/public_raw.train.csv')
test_raw = pd.read_csv('../data/public_raw.test.csv')

train_raw['is_train']=1
test_raw['is_train']=0

df = pd.concat([train_raw, test_raw],sort=False)

rep_cols = {'ID':'ID', 
 '板温':'board_t', 
 '现场温度':'env_t', 
 '光照强度':'light_strength', 
 '转换效率':'efficiency', 
 '转换效率A':'efficiency_A', 
 '转换效率B':'efficiency_B', 
 '转换效率C':'efficiency_C', 
 '电压A':'V_A',
 '电压B':'V_B', 
 '电压C':'V_C', 
 '电流A':'I_A', 
 '电流B':'I_B', 
 '电流C':'I_C', 
 '功率A':'P_A', 
 '功率B':'P_B', 
 '功率C':'P_C', 
 '平均功率':'P_avg', 
 '风速':'wind_speed',
 '风向':'wind_direction', 
 '发电量':'y'
}

df.rename(index=str, columns=rep_cols, inplace=True)

df.sort_values(by=['ID'],ascending=True, inplace=True)

df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 2.3.特征工程(完全使用原始特征)

# %% [markdown]
# ## 2.4.训练

# %% [markdown]
# ### 2.4.1.准备工作

# %%
# CV时不方便shuffle，因此准备训练集和测试集时shuffle
df = df.sample(frac=1).reset_index(drop=True)

# 准备训练集和测试集
train = df[df['is_train']==1]
test = df[df['is_train']==0]
print('训练集数量:'+str(len(train)))
print('测试集数量:'+str(len(test)))

# 准备训练集合输入矩阵和输出矩阵
train_X = train.drop(['y','is_train','I_B','I_C'],axis=1)
train_Y = train['y']

# 准备测试集合输入矩阵
test_X = test.drop(['y','is_train','I_B','I_C'],axis=1)

# 准备测试集合输出矩阵容器
ans=pd.DataFrame()
ans['ID']=test_X['ID']
# Out:
# 训练集数量:9000
# 测试集数量:8409

# %%
# 定义打分函数,  SCORE = 1/(1+RMSE)
def cal_score(mse):
    if isinstance(mse, float):
        return 1 / (1 + math.sqrt(mse))
    else:
        return np.divide(1, 1 + np.sqrt(mse))

# def cal_score(mse):
#     return np.divide(1, 1 + np.sqrt(mse))


# 定义交叉验证函数  
def cross_validate(models, X, Y, cv=5):
    model_name, mse_avg, score_avg = [], [], []
    for i, model in enumerate(models):
        #获取模型名
        name = str(i + 1) + '.' + str(model) 
#         print(i + 1,'- Model:', str(model).split('(')[0])
        print(name)
#         model_name.append(str(i + 1) + '.' + str(model).split('(')[0])
        model_name.append(name.split('(')[0])
        #计算metric
#         strat_k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=2018)
#         folds=strat_k_fold.split(X,Y)
        #apply shuffling to cross_val_score
#         strat_k_fold = StratifiedKFold(n_splits=cv, shuffle=True, random_state=0)
        nmse = cross_val_score(model, X, Y, cv=cv, scoring='neg_mean_squared_error')
    
#         nmse = cross_val_score(model, X, Y, cv=cv, scoring='neg_mean_squared_error')
        avg_mse = np.average(-nmse)
        mse_avg.append(avg_mse)
        #计算分数
        scores = cal_score(-nmse)
        avg_score = np.average(scores)    
        score_avg.append(avg_score)
        print('MSE:', -nmse)
        print('Score:', scores)
        print('Average MSE:', avg_mse, ' - Score:', avg_score, '\n')
    res = pd.DataFrame()
    res['Model'] = model_name
    res['Avg MSE'] = mse_avg
    res['Avg Score'] = score_avg
    return res

# %% [markdown]
# ### 2.4.2.Cross Validation（LightGBM/XGBoost/RF/GBM）

# %%
#基学习器

xgbt1 = xgb.XGBRegressor(n_estimators=950, max_depth=3, max_features='sqrt', random_state=321, n_jobs=8)
xgbt2 = xgb.XGBRegressor(n_estimators=1000, max_depth=3, max_features='sqrt', random_state=456, n_jobs=8)
xgbt3 = xgb.XGBRegressor(n_estimators=1100, max_depth=3, max_features='sqrt', random_state=789, n_jobs=8)
# n_estimators=1000  max_depth=5  'sqrt'  GradientBoostingRegressor 最佳参数 ,learning_rate=0.08
gbdt1 = GradientBoostingRegressor(n_estimators=800, max_depth=4, max_features='log2', random_state=123,learning_rate=0.08)
gbdt2 = GradientBoostingRegressor(n_estimators=900, max_depth=4, max_features='log2', random_state=456,learning_rate=0.08)
gbdt3 = GradientBoostingRegressor(n_estimators=1000, max_depth=5, max_features='log2', random_state=789,learning_rate=0.08)
# n_estimators=700, max_features='auto', random_state=2, n_jobs=8,max_depth=10
forest1 = RandomForestRegressor(n_estimators=800, max_features='sqrt', random_state=7, n_jobs=8)
forest2 = RandomForestRegressor(n_estimators=900, max_features='log2', random_state=9, n_jobs=8)
forest3 = RandomForestRegressor(n_estimators=900, max_features='sqrt', random_state=11, n_jobs=8) 

lgb1 = LGBMRegressor(n_estimators=900, max_depth=5, random_state=5, n_jobs=8) 
lgb2 = LGBMRegressor(n_estimators=850, max_depth=4, random_state=7, n_jobs=8)
lgb3 = LGBMRegressor(n_estimators=720, max_depth=4, random_state=9, n_jobs=8)

# %%
regrs = [
    xgbt1, gbdt1, forest1, lgb1,
    xgbt2, gbdt2, forest2, lgb2,
    xgbt3, gbdt3, forest3, lgb3
]

# %%
cross_validate(
    models=[    
        xgbt3, gbdt3, forest3, lgb3
    ],
    X = train_X, 
    Y = train_Y
)
# Out:
# 1.XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, max_features='sqrt', min_child_weight=1, missing=None,
#        n_estimators=1100, n_jobs=8, nthread=None, objective='reg:linear',
#        random_state=789, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# MSE: [0.02068348 0.02547938 0.08352001 0.03153837 0.01621974]
# Score: [0.87426533 0.86234952 0.77579622 0.84919166 0.88703067]
# Average MSE: 0.035488194758418856  - Score: 0.8497266809807673
#
# 2.GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.08, loss='ls', max_depth=5,
#              max_features='log2', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=1000,
#              presort='auto', random_state=789, subsample=1.0, verbose=0,
#              warm_start=False)
# MSE: [0.01580284 0.02103803 0.07624213 0.02000487 0.01564169]
# Score: [0.88832878 0.87332817 0.7836255  0.87608744 0.88883616]
# Average MSE: 0.029745911733431017  - Score: 0.8620412117062337
#
# 3.RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=900, n_jobs=8,
#            oob_score=False, random_state=11, verbose=0, warm_start=False)
# MSE: [0.02091284 0.03024908 0.08612365 0.01948263 0.01675874]
# Score: [0.87365795 0.8518449  0.77311519 0.87751613 0.88538234]
# Average MSE: 0.034705386430985044  - Score: 0.8523033046767641
#
# 4.LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#        learning_rate=0.1, max_depth=4, min_child_samples=20,
#        min_child_weight=0.001, min_split_gain=0.0, n_estimators=720,
#        n_jobs=8, num_leaves=31, objective=None, random_state=9,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=1.0,
#        subsample_for_bin=200000, subsample_freq=0)
# MSE: [0.01762438 0.02338028 0.08075613 0.01988582 0.01772558]
# Score: [0.88280198 0.86737331 0.77870932 0.87641107 0.88250549]
# Average MSE: 0.031874436882170946  - Score: 0.8575602348002389
#                          Model   Avg MSE  Avg Score
# 0               1.XGBRegressor  0.035488   0.849727
# 1  2.GradientBoostingRegressor  0.029746   0.862041
# 2      3.RandomForestRegressor  0.034705   0.852303
# 3              4.LGBMRegressor  0.031874   0.857560

# %% [markdown]
# ### 2.4.3.使用LightGBM/XGBoost/RF/GBM多种模型训练后融合

# %%
class Stacker(object):
    def __init__(self, n_splits, stacker, base_models):
        self.n_splits = n_splits
        self.stacker = stacker
        self.base_models = base_models
    
    # Train_X: 原始训练集输入矩阵, Train_Y: 原始训练集输出矩阵, Test_X: 原始测试集输入矩阵
    def fit_predict(self, Train_X, Train_Y, Test_X):
        Train_X = np.array(Train_X)
        Train_Y = np.array(Train_Y)
        Test_X = np.array(Test_X)

        folds = list(KFold(n_splits=self.n_splits, shuffle=True, random_state=2018).split(Train_X, Train_Y))       
        
        # 以基学习器预测结果为特征的 stacker训练数据 与 stacker预测数据
        # 原始训练集预测结果容器
        S_train = np.zeros((Train_X.shape[0], len(self.base_models)))
        # 原始测试集预测结果容器
        S_predict = np.zeros((Test_X.shape[0], len(self.base_models)))
        
        for n_model, regr in enumerate(self.base_models):
            print(n_model + 1, 'Base model:', str(regr).split('(')[0])
            S_predict_i = np.zeros((Test_X.shape[0], self.n_splits))
            
            for n_fold, (train_idx, test_idx) in enumerate(folds):
                # 将X分为训练集与测试集
                X_train_fold, Y_train_fold, X_test_fold, Y_test_fold = Train_X[train_idx], Train_Y[train_idx], Train_X[test_idx], Train_Y[test_idx]
                print ('Fit fold', (n_fold+1), '...')
                regr.fit(X_train_fold, Y_train_fold)
                Y_pred = regr.predict(X_test_fold)
                # 每折训练得到的模型根据原始训练集中的测试折的输入矩阵预测
                S_train[test_idx, n_model] = Y_pred
                # 每折训练得到的模型根据原始测试集输入矩阵预测
                S_predict_i[:, n_fold] = regr.predict(Test_X)
            
            S_predict[:, n_model] = S_predict_i.mean(axis=1)

        nmse_score = cross_val_score(self.stacker, S_train, Train_Y, cv=5, scoring='neg_mean_squared_error')
        print('CV MSE:', -nmse_score)
        print('Stacker AVG MSE:', -nmse_score.mean(), 'Stacker AVG Score:', np.mean(np.divide(1, 1 + np.sqrt(-nmse_score))))

        self.stacker.fit(S_train, Train_Y)
        res = self.stacker.predict(S_predict)
        return res, S_train, S_predict

# %%
stacking_model = SVR(C=100, gamma=0.01, epsilon=0.01)
stacker = Stacker(5, stacking_model, regrs)
pred_stack, S_train_data, S_predict_data = stacker.fit_predict(train_X, train_Y, test_X)
# Out:
# 1 Base model: XGBRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 2 Base model: GradientBoostingRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 3 Base model: RandomForestRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 4 Base model: LGBMRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 5 Base model: XGBRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 6 Base model: GradientBoostingRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 7 Base model: RandomForestRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 8 Base model: LGBMRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 9 Base model: XGBRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 10 Base model: GradientBoostingRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 11 Base model: RandomForestRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 12 Base model: LGBMRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# CV MSE: [0.56507773 0.02244865 0.02713265 0.02094513 0.07759294]
# Stacker AVG MSE: 0.1426394184025874 Stacker AVG Score: 0.7909689115097418

# %%
#local CV: 0.7909689115097466

ans['y_n_shuffle'] = pred_stack
ans['y_n_shuffle'].describe()

# %%
#local CV: 0.8697213790417854

ans['y_shuffle'] = pred_stack
ans['y_shuffle'].describe()
# Out:
# count    8409.000000
# mean        5.695812
# std         3.459761
# min        -0.131349
# 25%         2.505766
# 50%         5.704603
# 75%         8.887224
# max        12.348426
# Name: y_shuffle, dtype: float64

# %% [markdown]
# # 3.增加数据清洗工序

# %% [markdown]
# ## 3.1.去重

# %%
# 准备训练集和测试集
train = df[df['is_train']==1]
test = df[df['is_train']==0]
print('训练集数量:'+str(len(train)))
print('测试集数量:'+str(len(test)))

# 对训练集进行去重
train.drop_duplicates(train.columns.drop('ID'), keep='first', inplace=True)
print('去重后训练集数量:'+str(len(train)))

# 准备训练集合输入矩阵和输出矩阵
train_X = train.drop(['y','is_train','I_B','I_C'],axis=1)
train_Y = train['y']

# 准备测试集合输入矩阵
test_X = test.drop(['y','is_train','I_B','I_C'],axis=1)

# 准备测试集合输出矩阵容器
ans=pd.DataFrame()
ans['ID']=test_X['ID']
# Out:
# 训练集数量:9000
# 测试集数量:8409
# 去重后训练集数量:8918
# C:\Users\Alex\Anaconda3\envs\python36\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
stacking_model = SVR(C=100, gamma=0.01, epsilon=0.01)
stacker = Stacker(5, stacking_model, regrs)
pred_stack, S_train_data, S_predict_data = stacker.fit_predict(train_X, train_Y, test_X)
# Out:
# 1 Base model: XGBRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 2 Base model: GradientBoostingRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 3 Base model: RandomForestRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 4 Base model: LGBMRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 5 Base model: XGBRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 6 Base model: GradientBoostingRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 7 Base model: RandomForestRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 8 Base model: LGBMRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 9 Base model: XGBRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 10 Base model: GradientBoostingRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 11 Base model: RandomForestRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 12 Base model: LGBMRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# CV MSE: [0.02759276 0.00923107 0.01391135 0.01278786 0.06848413]
# Stacker AVG MSE: 0.026401435241725214 Stacker AVG Score: 0.8710764504503057

# %%
#local CV: 0.8710764504503057

ans['y_drop_duplicate'] = pred_stack
ans['y_drop_duplicate'].describe()
# Out:
# count    8409.000000
# mean        5.696612
# std         3.457480
# min        -0.117571
# 25%         2.510122
# 50%         5.704925
# 75%         8.886383
# max        12.132167
# Name: y_drop_duplicate, dtype: float64

# %% [markdown]
# ## 3.2.异常值处理:增加异常修正值特征(异常通过离群程度定义)

# %%
rolling_mask_two = [-i for i in range(1,2)]+[i for i in range(1,2)]
rolling_mask_four = [-i for i in range(1,3)]+[i for i in range(1,3)]
rolling_mask_six = [-i for i in range(1,4)]+[i for i in range(1,4)]
rolling_mask_eight = [-i for i in range(1,5)]+[i for i in range(1,5)]
rolling_mask_ten = [-i for i in range(1,6)]+[i for i in range(1,6)]

# %%
# 由于训练集中存在重复数据:1)连续重复数据 2)电学测量值为0的重复数据

# 对于训练集,重复项全部去除
train_raw = pd.read_csv('../data/public_raw.train.csv')
print('去重前训练集条数:' +str(train_raw.shape[0]))
train_raw.drop_duplicates(train_raw.columns.drop('ID'), keep='first', inplace=True)
print('去重后训练集条数:' +str(train_raw.shape[0]))

# 对于测试集,仅仅通过ID去除电学测量值为0的重复数据
test_raw = pd.read_csv('../data/public_raw.test.csv')

# 在去重前准备完整测试集ID
ans=pd.DataFrame()
ans['ID']=test_raw['ID']

# 电学测量量全为0的异常点个数
zero_sample_ID = test_raw[test_raw[(test_raw == 0) | (test_raw == 0.)].count(axis=1) > 13]['ID'].tolist()
print('测试集中电学测量量全为0的异常点个数为: '+str(len(zero_sample_ID)))

# 根据ID全部去除
print('去重前测试集条数:' +str(test_raw.shape[0]))
test_raw = test_raw[~test_raw['ID'].isin(zero_sample_ID)].reset_index(drop=True)
print('去重后测试集条数:' +str(test_raw.shape[0]))




train_raw['is_train']=1
test_raw['is_train']=0

df = pd.concat([train_raw, test_raw],sort=False)

rep_cols = {'ID':'ID', 
 '板温':'board_t', 
 '现场温度':'env_t', 
 '光照强度':'light_strength', 
 '转换效率':'efficiency', 
 '转换效率A':'efficiency_A', 
 '转换效率B':'efficiency_B', 
 '转换效率C':'efficiency_C', 
 '电压A':'V_A',
 '电压B':'V_B', 
 '电压C':'V_C', 
 '电流A':'I_A', 
 '电流B':'I_B', 
 '电流C':'I_C', 
 '功率A':'P_A', 
 '功率B':'P_B', 
 '功率C':'P_C', 
 '平均功率':'P_avg', 
 '风速':'wind_speed',
 '风向':'wind_direction', 
 '发电量':'y'
}

df.rename(index=str, columns=rep_cols, inplace=True)

df.sort_values(by=['ID'],ascending=True, inplace=True)

df.reset_index(drop=True, inplace=True)
# Out:
# 去重前训练集条数:9000
# 去重后训练集条数:8918
# 测试集中电学测量量全为0的异常点个数为: 46
# 去重前测试集条数:8409
# 去重后测试集条数:8363

# %%
# #非零连续重复记录
# df_fd = df.copy()
# df_fd['is_duplicate']=df_fd.duplicated(df_fd.columns.drop('ID'))

# df_fd[(df_fd['is_duplicate']==True) & (df_fd['V_A']!=0)]

# %%
#计算偏差率的辅助列
# for c in ['I_A','I_B','I_C','V_A','V_B','V_C']:
for c in ['I_A','I_B','I_C']:
    df[c+'_avg_sequence'] = np.nanmean([df[c].shift(i) for i in rolling_mask_eight],axis=0)
    df[c+'_exception_ratio'] = np.abs(df[c]-df[c+'_avg_sequence'])/df[c+'_avg_sequence']
    df[c+'_cor'] = df[c]
    
    #out of range
    oor_index = df[df[c]>20].index
    print(oor_index)
    
    outlier_index = df[df[c+'_exception_ratio']>1.6].index
    print(outlier_index)
    
    ab_index = pd.Int64Index(set(list(oor_index)+list(outlier_index)))
    print(ab_index)
    
    ab_data = df.loc[ab_index].sort_values(by='ID', ascending=True)
    
    # 上下记录均值替代异常值
    for idx, line in ab_data.iterrows():
        ID = line['ID']
        value = line[c]
        
        index = df[df['ID'] == ID].index
            
        before_offset = 1
        while (idx - before_offset)in ab_index:
            before_offset += 1

        after_offset = 1
        while (idx + after_offset) in ab_index:
            after_offset += 1
    
        print('ID :' + str(ID))
        print(value, 'is abnormal as value of ',c)
        replace_value = (df.loc[index - before_offset, c].values + df.loc[index + after_offset, c].values) / 2
        df.loc[index, c+'_cor'] = replace_value[0]
        print('Has been replaced by '+str(replace_value[0]))

        
        
        
        
        
for c in ['V_A','V_B','V_C']:
    df[c+'_avg_sequence'] = np.nanmean([df[c].shift(i) for i in rolling_mask_eight],axis=0)
    df[c+'_exception_ratio'] = np.abs(df[c]-df[c+'_avg_sequence'])/df[c+'_avg_sequence']
    df[c+'_cor'] = df[c]
    
    #out of range
    oor_index = df[(df[c]>800)|(df[c]<500)].index
    print(oor_index)
    
    outlier_index = df[df[c+'_exception_ratio']>1.6].index
    print(outlier_index)
    
    ab_index = pd.Int64Index(set(list(oor_index)+list(outlier_index)))
    print(ab_index)
    
    ab_data = df.loc[ab_index].sort_values(by='ID', ascending=True)
    
    # 上下记录均值替代异常值
    for idx, line in ab_data.iterrows():
        ID = line['ID']
        value = line[c]
        
        index = df[df['ID'] == ID].index
            
        before_offset = 1
        while (idx - before_offset)in ab_index:
            before_offset += 1

        after_offset = 1
        while (idx + after_offset) in ab_index:
            after_offset += 1
    
        print('ID :' + str(ID))
        print(value, 'is abnormal as value of ',c)
        replace_value = (df.loc[index - before_offset, c].values + df.loc[index + after_offset, c].values) / 2
        df.loc[index, c+'_cor'] = replace_value[0]
        print('Has been replaced by '+str(replace_value[0]))

        
        

        
df['P_A_cor']=df['I_A_cor']*df['V_A_cor']
df['P_B_cor']=df['I_B_cor']*df['V_B_cor']
df['P_C_cor']=df['I_C_cor']*df['V_C_cor']
df['P_avg_cor']=1/3*(df['P_A_cor']+df['P_B_cor']+df['P_C_cor'])


df.drop(columns=['I_A','I_B','I_C','V_A','V_B','V_C','P_A','P_B','P_C','P_avg'],axis=1,inplace=True)
# df.drop(columns=['I_A_avg_sequence','I_A_exception_ratio','I_B_avg_sequence','I_B_exception_ratio','I_C_avg_sequence','I_C_exception_ratio','V_B_avg_sequence','V_B_exception_ratio','V_A_avg_sequence','V_A_exception_ratio','V_C_avg_sequence','V_C_exception_ratio',],axis=1,inplace=True)
# 0.85661

df.head(20)
    
    


    
    
    
    
    
    
    
    
    

# #异常修正值由滚动平均值替代（前后各4个点的平均值）
# for c in ['I_A','I_B','I_C','V_A','V_B','V_C']:

    
# for idx, line in df.iterrows():
#     for c in ['I_A','I_B','I_C','V_A','V_B','V_C']:
#         if line[c+'_exception_ratio']>1.6:
#             print(str(line[c]) + ' is abnormal as value of ' + c)
#             line.loc[c+'_corrected'] = line[c+'_avg_sequence']
#             print('Has been replaced by '+str(line[c+'_avg_sequence']))
# Out:
# Int64Index([], dtype='int64')
# Int64Index([  522,   524,   526,   668,   852,  1362,  1549,  1709,  2056,
#              3085,  3230,  3232,  3279,  3281,  3287,  3292,  3294,  3405,
#              5037, 16292],
#            dtype='int64')
# Int64Index([ 3232, 16292,  2056,   522,   524,  1549,   526,  1709,  3085,
#              3279,  1362,  3281,   852,  3292,  3405,  3287,   668,  3294,
#              3230,  5037],
#            dtype='int64')
# ID :591.0
# 6.68 is abnormal as value of  I_A
# Has been replaced by 0.9400000000000001
# ID :593.0
# 6.68 is abnormal as value of  I_A
# Has been replaced by 1.56
# ID :595.0
# 6.77 is abnormal as value of  I_A
# Has been replaced by 0.9650000000000001
# ID :737.0
# 6.53 is abnormal as value of  I_A
# Has been replaced by 0.345
# ID :948.0
# 6.87 is abnormal as value of  I_A
# Has been replaced by 0.33
# ID :1519.0
# 7.04 is abnormal as value of  I_A
# Has been replaced by 0.77
# ID :1717.0
# 6.81 is abnormal as value of  I_A
# Has been replaced by 0.33999999999999997
# ID :1894.0
# 7.1 is abnormal as value of  I_A
# Has been replaced by 0.745
# ID :2271.0
# 7.22 is abnormal as value of  I_A
# Has been replaced by 1.105
# ID :3393.0
# 6.64 is abnormal as value of  I_A
# Has been replaced by 0.335
# ID :3538.0
# 6.56 is abnormal as value of  I_A
# Has been replaced by 0.8999999999999999
# ID :3540.0
# 6.5 is abnormal as value of  I_A
# Has been replaced by 0.88
# ID :3597.0
# 6.93 is abnormal as value of  I_A
# Has been replaced by 0.315
# ID :3599.0
# 6.97 is abnormal as value of  I_A
# Has been replaced by 0.32
# ID :3605.0
# 7.01 is abnormal as value of  I_A
# Has been replaced by 0.325
# ID :3610.0
# 6.94 is abnormal as value of  I_A
# Has been replaced by 0.33
# ID :3612.0
# 7.13 is abnormal as value of  I_A
# Has been replaced by 0.335
# ID :3723.0
# 7.21 is abnormal as value of  I_A
# Has been replaced by 0.355
# ID :5521.0
# 1.66 is abnormal as value of  I_A
# Has been replaced by 0.355
# ID :16879.0
# 6.87 is abnormal as value of  I_A
# Has been replaced by 1.755
# Int64Index([13, 852, 974, 1057, 1228, 1408, 3279, 3281, 3285, 3287, 3289], dtype='int64')
# Int64Index([   13,   495,   668,   852,   974,  1057,  1228,  1362,  1408,
#              1549,  1709,  2056,  3085,  3230,  3231,  3232,  3279,  3281,
#              3285,  3287,  3289,  3294,  3405,  4040,  5037,  7214, 16255,
#             16283, 16291, 16460],
#            dtype='int64')
# Int64Index([ 1408,  2056,  3085,    13,  1549, 16283,   668,  3230,  3231,
#              3232,  1057, 16291,  1709,  5037,  7214,  4040,  1228,  3405,
#               974,  3279, 16460,  3281,  1362,   852,  3285,  3287,  3289,
#              3294,   495, 16255],
#            dtype='int64')
# ID :22.0
# 645.39 is abnormal as value of  I_B
# Has been replaced by 2.84
# ID :543.0
# 6.78 is abnormal as value of  I_B
# Has been replaced by 1.67
# ID :737.0
# 6.45 is abnormal as value of  I_B
# Has been replaced by 0.35
# ID :948.0
# 638.94 is abnormal as value of  I_B
# Has been replaced by 0.3
# ID :1070.0
# 653.71 is abnormal as value of  I_B
# Has been replaced by 5.32
# ID :1173.0
# 649.75 is abnormal as value of  I_B
# Has been replaced by 6.275
# ID :1362.0
# 652.02 is abnormal as value of  I_B
# Has been replaced by 5.35
# ID :1519.0
# 7.1 is abnormal as value of  I_B
# Has been replaced by 0.37
# ID :1565.0
# 653.23 is abnormal as value of  I_B
# Has been replaced by 5.12
# ID :1717.0
# 6.83 is abnormal as value of  I_B
# Has been replaced by 0.36
# ID :1894.0
# 7.13 is abnormal as value of  I_B
# Has been replaced by 0.365
# ID :2271.0
# 7.28 is abnormal as value of  I_B
# Has been replaced by 0.36
# ID :3393.0
# 6.65 is abnormal as value of  I_B
# Has been replaced by 0.365
# ID :3538.0
# 6.62 is abnormal as value of  I_B
# Has been replaced by 0.355
# ID :3539.0
# 6.62 is abnormal as value of  I_B
# Has been replaced by 0.355
# ID :3540.0
# 6.56 is abnormal as value of  I_B
# Has been replaced by 0.355
# ID :3597.0
# 643.45 is abnormal as value of  I_B
# Has been replaced by 0.335
# ID :3599.0
# 643.58 is abnormal as value of  I_B
# Has been replaced by 0.34
# ID :3603.0
# 643.75 is abnormal as value of  I_B
# Has been replaced by 0.34
# ID :3605.0
# 643.83 is abnormal as value of  I_B
# Has been replaced by 0.34
# ID :3607.0
# 643.94 is abnormal as value of  I_B
# Has been replaced by 0.34
# ID :3612.0
# 7.05 is abnormal as value of  I_B
# Has been replaced by 1.15
# ID :3723.0
# 7.06 is abnormal as value of  I_B
# Has been replaced by 0.35
# ID :4401.0
# 1.77 is abnormal as value of  I_B
# Has been replaced by 0.38
# ID :5521.0
# 6.72 is abnormal as value of  I_B
# Has been replaced by 0.375
# ID :7742.0
# 1.38 is abnormal as value of  I_B
# Has been replaced by 0.37
# ID :16842.0
# 8.86 is abnormal as value of  I_B
# Has been replaced by 3.25
# ID :16870.0
# 7.49 is abnormal as value of  I_B
# Has been replaced by 1.77
# ID :16878.0
# 5.44 is abnormal as value of  I_B
# Has been replaced by 2.015
# ID :17048.0
# 8.14 is abnormal as value of  I_B
# Has been replaced by 2.05
# Int64Index([  522,   523,   524,   525,  1059,  1362,  1709,  1936,  2022,
#              2056,  3232,  3292,  3293,  3294,  5037, 15852],
#            dtype='int64')
# Int64Index([  522,   523,   524,   525,   668,   852,  1059,  1362,  1549,
#              1709,  1936,  2022,  2056,  3085,  3232,  3279,  3281,  3285,
#              3287,  3292,  3293,  3294,  3405,  4040,  5037, 15852, 16255,
#             16278, 16283, 16292],
#            dtype='int64')
# Int64Index([ 2056,   522,   523,   524,   525,  1549,  3085,  1936, 16278,
#             16283,   668,  3232,  1059, 16292,  1709,  5037,  4040,  3405,
#              3279,  3281,  1362,   852,  3285,  3287,  3292,  3293,  3294,
#              2022, 15852, 16255],
#            dtype='int64')
# ID :591.0
# 640.77 is abnormal as value of  I_C
# Has been replaced by 3.56
# ID :592.0
# 640.77 is abnormal as value of  I_C
# Has been replaced by 3.56
# ID :593.0
# 640.85 is abnormal as value of  I_C
# Has been replaced by 3.56
# ID :594.0
# 640.85 is abnormal as value of  I_C
# Has been replaced by 3.56
# ID :737.0
# 6.52 is abnormal as value of  I_C
# Has been replaced by 0.345
# ID :948.0
# 2.37 is abnormal as value of  I_C
# Has been replaced by 0.575
# ID :1175.0
# 649.96 is abnormal as value of  I_C
# Has been replaced by 4.21
# ID :1519.0
# 639.04 is abnormal as value of  I_C
# Has been replaced by 0.745
# ID :1717.0
# 6.82 is abnormal as value of  I_C
# Has been replaced by 0.375
# ID :1894.0
# 635.6 is abnormal as value of  I_C
# Has been replaced by 0.7949999999999999
# ID :2137.0
# 652.04 is abnormal as value of  I_C
# Has been replaced by 5.66
# ID :2223.0
# 649.69 is abnormal as value of  I_C
# Has been replaced by 3.01
# ID :2271.0
# 639.06 is abnormal as value of  I_C
# Has been replaced by 1.12
# ID :3393.0
# 6.52 is abnormal as value of  I_C
# Has been replaced by 0.375
# ID :3540.0
# 647.62 is abnormal as value of  I_C
# Has been replaced by 3.4699999999999998
# ID :3597.0
# 2.7 is abnormal as value of  I_C
# Has been replaced by 0.24000000000000002
# ID :3599.0
# 3.35 is abnormal as value of  I_C
# Has been replaced by 0.25
# ID :3603.0
# 3.16 is abnormal as value of  I_C
# Has been replaced by 0.48
# ID :3605.0
# 3.36 is abnormal as value of  I_C
# Has been replaced by 0.7
# ID :3610.0
# 644.15 is abnormal as value of  I_C
# Has been replaced by 0.37
# ID :3611.0
# 644.15 is abnormal as value of  I_C
# Has been replaced by 0.37
# ID :3612.0
# 644.16 is abnormal as value of  I_C
# Has been replaced by 0.37
# ID :3723.0
# 7.08 is abnormal as value of  I_C
# Has been replaced by 0.39
# ID :4401.0
# 3.31 is abnormal as value of  I_C
# Has been replaced by 0.405
# ID :5521.0
# 641.85 is abnormal as value of  I_C
# Has been replaced by 0.36
# ID :16437.0
# 32.91 is abnormal as value of  I_C
# Has been replaced by 7.82
# ID :16842.0
# 8.39 is abnormal as value of  I_C
# Has been replaced by 3.0549999999999997
# ID :16865.0
# 7.99 is abnormal as value of  I_C
# Has been replaced by 2.3
# ID :16870.0
# 8.05 is abnormal as value of  I_C
# Has been replaced by 2.36
# ID :16879.0
# 6.72 is abnormal as value of  I_C
# Has been replaced by 3.9899999999999998
# Int64Index([  13,  169,  172,  173,  174,  494,  495,  522,  523,  524,  525,
#              526,  668,  852,  974, 1057, 1170, 1228, 1362, 1408, 1509, 1549,
#             1709, 2022, 2056, 2199, 2550, 2722, 2870, 3085, 3113, 3230, 3231,
#             3232, 3279, 3281, 3285, 3287, 3289, 3292, 3294, 3405, 5037, 6912],
#            dtype='int64')
# Int64Index([13, 852, 974, 1057, 1228, 1408, 2722, 3279, 3281, 3285, 3287,
#             3289],
#            dtype='int64')
# Int64Index([1408, 6912, 2056,  522,  523,  524,   13,  525,  526, 1549, 3085,
#             1170, 2199,  668, 3230, 3231, 3232, 1057, 2722,  169, 3113,  172,
#              173,  174, 1709, 5037, 2870, 1228, 3405,  974, 3279, 3281, 1362,
#              852, 3285, 3287, 3289, 3292, 3294, 1509, 2022,  494,  495, 2550],
#            dtype='int64')
# ID :22.0
# 65382.0 is abnormal as value of  V_A
# Has been replaced by 725.0
# ID :190.0
# 0.0 is abnormal as value of  V_A
# Has been replaced by 602.0
# ID :198.0
# 493.0 is abnormal as value of  V_A
# Has been replaced by 512.0
# ID :199.0
# 486.0 is abnormal as value of  V_A
# Has been replaced by 512.0
# ID :200.0
# 480.0 is abnormal as value of  V_A
# Has been replaced by 512.0
# ID :542.0
# 264.0 is abnormal as value of  V_A
# Has been replaced by 678.5
# ID :543.0
# 290.0 is abnormal as value of  V_A
# Has been replaced by 678.5
# ID :591.0
# 36.0 is abnormal as value of  V_A
# Has been replaced by 687.0
# ID :592.0
# 36.0 is abnormal as value of  V_A
# Has been replaced by 687.0
# ID :593.0
# 37.0 is abnormal as value of  V_A
# Has been replaced by 687.0
# ID :594.0
# 37.0 is abnormal as value of  V_A
# Has been replaced by 687.0
# ID :595.0
# 37.0 is abnormal as value of  V_A
# Has been replaced by 687.0
# ID :737.0
# 37.0 is abnormal as value of  V_A
# Has been replaced by 650.0
# ID :948.0
# 65394.0 is abnormal as value of  V_A
# Has been replaced by 687.5
# ID :1070.0
# 65477.0 is abnormal as value of  V_A
# Has been replaced by 697.5
# ID :1173.0
# 65408.0 is abnormal as value of  V_A
# Has been replaced by 707.0
# ID :1286.0
# 310.0 is abnormal as value of  V_A
# Has been replaced by 715.5
# ID :1362.0
# 65386.0 is abnormal as value of  V_A
# Has been replaced by 702.0
# ID :1519.0
# 77.0 is abnormal as value of  V_A
# Has been replaced by 711.0
# ID :1565.0
# 65420.0 is abnormal as value of  V_A
# Has been replaced by 697.5
# ID :1666.0
# 293.0 is abnormal as value of  V_A
# Has been replaced by 681.5
# ID :1717.0
# 36.0 is abnormal as value of  V_A
# Has been replaced by 687.5
# ID :1894.0
# 74.0 is abnormal as value of  V_A
# Has been replaced by 729.5
# ID :2223.0
# 297.0 is abnormal as value of  V_A
# Has been replaced by 709.0
# ID :2271.0
# 114.0 is abnormal as value of  V_A
# Has been replaced by 729.0
# ID :2414.0
# 292.0 is abnormal as value of  V_A
# Has been replaced by 703.5
# ID :2797.0
# 305.0 is abnormal as value of  V_A
# Has been replaced by 688.5
# ID :2986.0
# 65515.0 is abnormal as value of  V_A
# Has been replaced by 691.5
# ID :3152.0
# 3.0 is abnormal as value of  V_A
# Has been replaced by 673.0
# ID :3393.0
# 34.0 is abnormal as value of  V_A
# Has been replaced by 659.0
# ID :3421.0
# 290.0 is abnormal as value of  V_A
# Has been replaced by 700.5
# ID :3538.0
# 36.0 is abnormal as value of  V_A
# Has been replaced by 658.0
# ID :3539.0
# 36.0 is abnormal as value of  V_A
# Has been replaced by 658.0
# ID :3540.0
# 36.0 is abnormal as value of  V_A
# Has been replaced by 658.0
# ID :3597.0
# 65419.0 is abnormal as value of  V_A
# Has been replaced by 700.0
# ID :3599.0
# 65419.0 is abnormal as value of  V_A
# Has been replaced by 698.5
# ID :3603.0
# 65420.0 is abnormal as value of  V_A
# Has been replaced by 696.0
# ID :3605.0
# 65420.0 is abnormal as value of  V_A
# Has been replaced by 694.0
# ID :3607.0
# 65420.0 is abnormal as value of  V_A
# Has been replaced by 695.0
# ID :3610.0
# 36.0 is abnormal as value of  V_A
# Has been replaced by 708.5
# ID :3612.0
# 37.0 is abnormal as value of  V_A
# Has been replaced by 704.0
# ID :3723.0
# 39.0 is abnormal as value of  V_A
# Has been replaced by 718.5
# ID :5521.0
# 36.0 is abnormal as value of  V_A
# Has been replaced by 689.5
# ID :7437.0
# 807.0 is abnormal as value of  V_A
# Has been replaced by 646.5
# Int64Index([   13,   169,   495,   522,   523,   524,   525,   526,   668,
#               852,   974,  1057,  1058,  1059,  1170,  1228,  1317,  1362,
#              1408,  1509,  1549,  1709,  1936,  2022,  2056,  2199,  2348,
#              2437,  2550,  2611,  2652,  2722,  2870,  3085,  3113,  3230,
#              3231,  3232,  3279,  3281,  3285,  3287,  3289,  3292,  3293,
#              3294,  3405,  4040,  5037,  5437,  5514,  6912,  7214, 14107,
#             15715, 15852],
#            dtype='int64')
# Int64Index([ 522,  523,  524,  525, 1059, 1317, 1362, 1709, 1936, 2022, 2056,
#             2348, 2437, 2550, 2611, 2652, 3232, 3292, 3293, 3294, 5037, 5514],
#            dtype='int64')
# Int64Index([ 1408,  6912,  2437,  2056,   522,   523,   524,    13,   525,
#               526,  1549,  1936,  1170,  3085,  2199, 14107,   668,  3230,
#              3231,  3232,  1057,  1058,  1059,  2722,  1317,   169,  3113,
#              2348,  1709,  5037,  7214,  2611,  2870,  5437,  4040,  1228,
#              3405,   974,  3279,  3281,  1362,   852,  3285,  3287,  3289,
#              2652,  3292,  3293,  3294,  5514, 15715,  1509,  2022, 15852,
#               495,  2550],
#            dtype='int64')
# ID :22.0
# 7.0 is abnormal as value of  V_B
# Has been replaced by 724.5
# ID :190.0
# 0.0 is abnormal as value of  V_B
# Has been replaced by 644.0
# ID :543.0
# 293.0 is abnormal as value of  V_B
# Has been replaced by 681.0
# ID :591.0
# 65402.0 is abnormal as value of  V_B
# Has been replaced by 682.0
# ID :592.0
# 65402.0 is abnormal as value of  V_B
# Has been replaced by 682.0
# ID :593.0
# 65403.0 is abnormal as value of  V_B
# Has been replaced by 682.0
# ID :594.0
# 65403.0 is abnormal as value of  V_B
# Has been replaced by 682.0
# ID :595.0
# 39.0 is abnormal as value of  V_B
# Has been replaced by 682.0
# ID :737.0
# 37.0 is abnormal as value of  V_B
# Has been replaced by 649.0
# ID :948.0
# 4.0 is abnormal as value of  V_B
# Has been replaced by 687.0
# ID :1070.0
# 41.0 is abnormal as value of  V_B
# Has been replaced by 694.0
# ID :1173.0
# 22.0 is abnormal as value of  V_B
# Has been replaced by 703.5
# ID :1174.0
# 22.0 is abnormal as value of  V_B
# Has been replaced by 703.5
# ID :1175.0
# 65406.0 is abnormal as value of  V_B
# Has been replaced by 703.5
# ID :1286.0
# 307.0 is abnormal as value of  V_B
# Has been replaced by 716.5
# ID :1362.0
# 23.0 is abnormal as value of  V_B
# Has been replaced by 698.5
# ID :1451.0
# 65454.0 is abnormal as value of  V_B
# Has been replaced by 682.5
# ID :1519.0
# 65387.0 is abnormal as value of  V_B
# Has been replaced by 712.5
# ID :1565.0
# 8.0 is abnormal as value of  V_B
# Has been replaced by 692.5
# ID :1666.0
# 255.0 is abnormal as value of  V_B
# Has been replaced by 684.5
# ID :1717.0
# 40.0 is abnormal as value of  V_B
# Has been replaced by 683.0
# ID :1894.0
# 65350.0 is abnormal as value of  V_B
# Has been replaced by 713.5
# ID :2137.0
# 65428.0 is abnormal as value of  V_B
# Has been replaced by 694.5
# ID :2223.0
# 65446.0 is abnormal as value of  V_B
# Has been replaced by 707.0
# ID :2271.0
# 65353.0 is abnormal as value of  V_B
# Has been replaced by 719.0
# ID :2414.0
# 296.0 is abnormal as value of  V_B
# Has been replaced by 701.5
# ID :2579.0
# 65481.0 is abnormal as value of  V_B
# Has been replaced by 682.0
# ID :2684.0
# 65438.0 is abnormal as value of  V_B
# Has been replaced by 687.0
# ID :2797.0
# 65512.0 is abnormal as value of  V_B
# Has been replaced by 687.0
# ID :2875.0
# 65455.0 is abnormal as value of  V_B
# Has been replaced by 684.5
# ID :2916.0
# 65508.0 is abnormal as value of  V_B
# Has been replaced by 675.0
# ID :2986.0
# 0.0 is abnormal as value of  V_B
# Has been replaced by 689.5
# ID :3152.0
# 33.0 is abnormal as value of  V_B
# Has been replaced by 668.5
# ID :3393.0
# 38.0 is abnormal as value of  V_B
# Has been replaced by 664.5
# ID :3421.0
# 300.0 is abnormal as value of  V_B
# Has been replaced by 699.0
# ID :3538.0
# 37.0 is abnormal as value of  V_B
# Has been replaced by 661.5
# ID :3539.0
# 37.0 is abnormal as value of  V_B
# Has been replaced by 661.5
# ID :3540.0
# 65463.0 is abnormal as value of  V_B
# Has been replaced by 661.5
# ID :3597.0
# 10.0 is abnormal as value of  V_B
# Has been replaced by 704.0
# ID :3599.0
# 5.0 is abnormal as value of  V_B
# Has been replaced by 699.0
# ID :3603.0
# 3.0 is abnormal as value of  V_B
# Has been replaced by 701.0
# ID :3605.0
# 11.0 is abnormal as value of  V_B
# Has been replaced by 698.0
# ID :3607.0
# 15.0 is abnormal as value of  V_B
# Has been replaced by 705.0
# ID :3610.0
# 65423.0 is abnormal as value of  V_B
# Has been replaced by 703.0
# ID :3611.0
# 65423.0 is abnormal as value of  V_B
# Has been replaced by 703.0
# ID :3612.0
# 65422.0 is abnormal as value of  V_B
# Has been replaced by 703.0
# ID :3723.0
# 42.0 is abnormal as value of  V_B
# Has been replaced by 698.0
# ID :4401.0
# 9.0 is abnormal as value of  V_B
# Has been replaced by 668.0
# ID :5521.0
# 65410.0 is abnormal as value of  V_B
# Has been replaced by 682.5
# ID :5939.0
# 15.0 is abnormal as value of  V_B
# Has been replaced by 715.5
# ID :6016.0
# 65505.0 is abnormal as value of  V_B
# Has been replaced by 666.0
# ID :7437.0
# 831.0 is abnormal as value of  V_B
# Has been replaced by 645.5
# ID :7742.0
# 32.0 is abnormal as value of  V_B
# Has been replaced by 681.0
# ID :14682.0
# 36.0 is abnormal as value of  V_B
# Has been replaced by 657.0
# ID :16299.0
# 18.0 is abnormal as value of  V_B
# Has been replaced by 633.5
# ID :16437.0
# 146.0 is abnormal as value of  V_B
# Has been replaced by 597.5
# Int64Index([   13,   125,   169,   464,   495,   522,   523,   524,   525,
#               526,   668,   852,  1057,  1058,  1059,  1170,  1228,  1317,
#              1362,  1408,  1509,  1549,  1709,  1936,  2022,  2056,  2199,
#              2348,  2437,  2550,  2611,  2652,  2722,  2867,  2870,  3085,
#              3113,  3230,  3231,  3232,  3279,  3280,  3281,  3285,  3286,
#              3287,  3288,  3289,  3292,  3293,  3294,  3405,  3939,  4040,
#              4271,  4816,  5037,  5437,  5514,  6912,  7214, 10368, 10369,
#             11272, 12248, 12622, 14107, 15852],
#            dtype='int64')
# Int64Index([ 125,  526,  668, 1170, 1509, 1549, 2199, 3085, 3113, 3230, 3231,
#             3283, 3284, 3290, 3291, 3405, 6912],
#            dtype='int64')
# Int64Index([ 1408,  6912, 10368, 10369,  2437,  2056, 11272,   522,   523,
#               524,    13,   525,   526,  1549,  1936,  1170,  3085,  3284,
#              2199, 14107,   668,  3230,  3231,  3232,  1057,  1058,  1059,
#              2722,  1317,  4816,   169,  3113,  2348,  1709,  5037,  4271,
#              7214,  2611,  2867,  2870,  5437,  4040,  1228,  3405, 12622,
#              3279,   464,  3280,  1362,  3281,   852,  3285,  3286,  3287,
#              3288,  3289, 12248,  3283,  2652,  3292,  3293,  3294,  5514,
#              3290,  3291,  3939,  1509,  2022, 15852,   495,  2550,   125],
#            dtype='int64')
# ID :22.0
# 107.0 is abnormal as value of  V_C
# Has been replaced by 722.5
# ID :135.0
# 65498.0 is abnormal as value of  V_C
# Has been replaced by 677.0
# ID :190.0
# 0.0 is abnormal as value of  V_C
# Has been replaced by 658.0
# ID :512.0
# 23.0 is abnormal as value of  V_C
# Has been replaced by 665.0
# ID :543.0
# 15.0 is abnormal as value of  V_C
# Has been replaced by 679.5
# ID :591.0
# 0.0 is abnormal as value of  V_C
# Has been replaced by 677.5
# ID :592.0
# 0.0 is abnormal as value of  V_C
# Has been replaced by 677.5
# ID :593.0
# 3.0 is abnormal as value of  V_C
# Has been replaced by 677.5
# ID :594.0
# 3.0 is abnormal as value of  V_C
# Has been replaced by 677.5
# ID :595.0
# 65406.0 is abnormal as value of  V_C
# Has been replaced by 677.5
# ID :737.0
# 65514.0 is abnormal as value of  V_C
# Has been replaced by 645.0
# ID :948.0
# 14.0 is abnormal as value of  V_C
# Has been replaced by 697.0
# ID :1173.0
# 250.0 is abnormal as value of  V_C
# Has been replaced by 706.5
# ID :1174.0
# 250.0 is abnormal as value of  V_C
# Has been replaced by 706.5
# ID :1175.0
# 27.0 is abnormal as value of  V_C
# Has been replaced by 706.5
# ID :1286.0
# 65438.0 is abnormal as value of  V_C
# Has been replaced by 716.5
# ID :1362.0
# 244.0 is abnormal as value of  V_C
# Has been replaced by 700.5
# ID :1451.0
# 27.0 is abnormal as value of  V_C
# Has been replaced by 682.0
# ID :1519.0
# 14.0 is abnormal as value of  V_C
# Has been replaced by 703.5
# ID :1565.0
# 260.0 is abnormal as value of  V_C
# Has been replaced by 695.5
# ID :1666.0
# 65460.0 is abnormal as value of  V_C
# Has been replaced by 684.0
# ID :1717.0
# 65396.0 is abnormal as value of  V_C
# Has been replaced by 680.5
# ID :1894.0
# 22.0 is abnormal as value of  V_C
# Has been replaced by 717.5
# ID :2137.0
# 30.0 is abnormal as value of  V_C
# Has been replaced by 695.5
# ID :2223.0
# 18.0 is abnormal as value of  V_C
# Has been replaced by 705.5
# ID :2271.0
# 14.0 is abnormal as value of  V_C
# Has been replaced by 726.0
# ID :2414.0
# 65470.0 is abnormal as value of  V_C
# Has been replaced by 698.5
# ID :2579.0
# 39.0 is abnormal as value of  V_C
# Has been replaced by 683.0
# ID :2684.0
# 26.0 is abnormal as value of  V_C
# Has been replaced by 685.5
# ID :2797.0
# 17.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :2875.0
# 23.0 is abnormal as value of  V_C
# Has been replaced by 683.0
# ID :2916.0
# 30.0 is abnormal as value of  V_C
# Has been replaced by 676.0
# ID :2986.0
# 89.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3149.0
# 5.0 is abnormal as value of  V_C
# Has been replaced by 668.5
# ID :3152.0
# 260.0 is abnormal as value of  V_C
# Has been replaced by 669.5
# ID :3393.0
# 65470.0 is abnormal as value of  V_C
# Has been replaced by 655.0
# ID :3421.0
# 65475.0 is abnormal as value of  V_C
# Has been replaced by 701.5
# ID :3538.0
# 65463.0 is abnormal as value of  V_C
# Has been replaced by 658.0
# ID :3539.0
# 65463.0 is abnormal as value of  V_C
# Has been replaced by 658.0
# ID :3540.0
# 18.0 is abnormal as value of  V_C
# Has been replaced by 658.0
# ID :3597.0
# 63.0 is abnormal as value of  V_C
# Has been replaced by 698.0
# ID :3598.0
# 63.0 is abnormal as value of  V_C
# Has been replaced by 698.0
# ID :3599.0
# 64.0 is abnormal as value of  V_C
# Has been replaced by 698.0
# ID :3601.0
# 693.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3602.0
# 693.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3603.0
# 67.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3604.0
# 67.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3605.0
# 67.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3606.0
# 67.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3607.0
# 68.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3608.0
# 704.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3609.0
# 704.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3610.0
# 7.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3611.0
# 7.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3612.0
# 5.0 is abnormal as value of  V_C
# Has been replaced by 686.5
# ID :3723.0
# 65440.0 is abnormal as value of  V_C
# Has been replaced by 704.5
# ID :4300.0
# 31.0 is abnormal as value of  V_C
# Has been replaced by 663.0
# ID :4401.0
# 99.0 is abnormal as value of  V_C
# Has been replaced by 664.5
# ID :4651.0
# 479.0 is abnormal as value of  V_C
# Has been replaced by 594.5
# ID :5264.0
# 10.0 is abnormal as value of  V_C
# Has been replaced by 674.0
# ID :5521.0
# 0.0 is abnormal as value of  V_C
# Has been replaced by 661.0
# ID :5939.0
# 137.0 is abnormal as value of  V_C
# Has been replaced by 714.5
# ID :6016.0
# 23.0 is abnormal as value of  V_C
# Has been replaced by 663.0
# ID :7437.0
# 65491.0 is abnormal as value of  V_C
# Has been replaced by 644.0
# ID :7742.0
# 30.0 is abnormal as value of  V_C
# Has been replaced by 665.5
# ID :10920.0
# 27.0 is abnormal as value of  V_C
# Has been replaced by 628.0
# ID :10921.0
# 27.0 is abnormal as value of  V_C
# Has been replaced by 628.0
# ID :11832.0
# 146.0 is abnormal as value of  V_C
# Has been replaced by 616.5
# ID :12814.0
# 14.0 is abnormal as value of  V_C
# Has been replaced by 671.0
# ID :13189.0
# 10.0 is abnormal as value of  V_C
# Has been replaced by 619.0
# ID :14682.0
# 316.0 is abnormal as value of  V_C
# Has been replaced by 655.0
# ID :16437.0
# 26.0 is abnormal as value of  V_C
# Has been replaced by 594.5
#     ID  board_t  env_t  light_strength  efficiency  efficiency_A  \
# 0    9   -19.33  -17.5              13      198.32        259.11
# 1   10   -19.14  -17.4              34       80.55        106.32
# 2   11   -18.73  -17.3              30       99.90        139.00
# 3   12   -17.54  -17.0              41       82.48        114.86
# 4   13   -16.68  -16.6              50       73.59         97.95
# 5   14   -15.43  -16.6              53       73.98        101.72
# 6   15   -14.60  -16.3              65       64.62         86.86
# 7   16   -14.10  -16.2              76       61.97         77.59
# 8   17   -13.27  -16.2              83       75.36         73.55
# 9   18   -12.41  -16.2              86       76.06         75.89
# 10  19   -11.25  -15.9              96       71.51         70.09
# 11  20   -10.77  -15.8             100       70.04         69.27
# 12  21   -10.77  -15.8             100       72.88         73.35
# 13  22   -10.77  -15.8             100     5699.37      16924.86
# 14  23    -9.12  -15.0             115       66.14         64.56
# 15  24    -8.33  -14.7             122       63.99         62.47
# 16  25    -6.96  -14.5             127       64.87         63.86
# 17  26    -6.46  -14.0             138       61.51         60.49
# 18  27    -5.52  -13.9             142       60.63         59.86
# 19  28    -5.54  -13.6             148       59.96         58.80
#
#     efficiency_B  efficiency_C  wind_speed  wind_direction     ...       \
# 0          42.17        293.66         0.3             273     ...
# 1          16.98        118.36         0.6             272     ...
# 2          21.20        139.51         0.8             275     ...
# 3          14.91        117.66         1.1             283     ...
# 4          14.70        108.12         0.9             277     ...
# 5          15.55        104.67         0.9             280     ...
# 6          13.09         93.92         1.1             280     ...
# 7          25.80         82.53         0.9             278     ...
# 8          73.36         79.16         0.7             280     ...
# 9          73.95         78.34         1.0             279     ...
# 10         70.09         74.35         1.5             277     ...
# 11         68.43         72.42         1.5             281     ...
# 12         72.88         72.42         1.5             281     ...
# 13        162.65         10.59         1.5             281     ...
# 14         65.10         68.75         0.9             277     ...
# 15         62.96         66.53         0.7             278     ...
# 16         64.93         65.83         0.9             281     ...
# 17         60.60         63.43         0.0             264     ...
# 18         59.86         62.17         0.0             265     ...
# 19         59.57         61.52         0.0             265     ...
#
#     V_B_avg_sequence  V_B_exception_ratio  V_B_cor  V_C_avg_sequence  \
# 0         715.750000             0.015019    705.0        725.000000
# 1         717.200000             0.011433    709.0        724.400000
# 2         717.833333             0.001161    717.0        724.833333
# 3         718.571429             0.004771    722.0        725.571429
# 4         720.000000             0.006944    715.0        724.250000
# 5         721.500000             0.007623    727.0        725.375000
# 6         723.375000             0.007776    729.0        725.125000
# 7         723.875000             0.005698    728.0        725.000000
# 8         724.625000             0.002243    723.0        725.125000
# 9         635.375000             0.147354    729.0        647.000000
# 10        635.625000             0.142183    726.0        647.000000
# 11        634.875000             0.134082    720.0        646.125000
# 12        633.000000             0.142180    723.0        645.250000
# 13        721.125000             0.990293    724.5        720.875000
# 14        629.250000             0.153754    726.0        641.500000
# 15        628.375000             0.141038    717.0        640.375000
# 16        626.750000             0.142401    716.0        638.625000
# 17        625.250000             0.138745    712.0        636.750000
# 18        712.375000             0.000877    713.0        712.125000
# 19        709.625000             0.000528    710.0        709.375000
#
#     V_C_exception_ratio  V_C_cor  P_A_cor  P_B_cor   P_C_cor    P_avg_cor
# 0              0.005517    721.0   909.72   148.05  1031.030   696.266667
# 1              0.000828    725.0   976.86   155.98  1087.500   740.113333
# 2              0.001610    726.0  1128.40   172.08  1132.560   811.013333
# 3              0.007679    720.0  1279.25   166.06  1310.400   918.570000
# 4              0.006559    729.0  1334.07   200.20  1472.580  1002.283333
# 5              0.000862    726.0  1474.60   225.37  1517.340  1072.436667
# 6              0.003965    728.0  1548.51   233.28  1674.400  1152.063333
# 7              0.001379    724.0  1619.93   538.72  1723.120  1293.923333
# 8              0.001551    724.0  1681.68  1677.36  1810.000  1723.013333
# 9              0.123648    727.0  1802.96  1756.89  1861.120  1806.990000
# 10             0.120556    725.0  1865.82  1865.82  1979.250  1903.630000
# 11             0.115883    721.0  1923.90  1900.80  2011.590  1945.430000
# 12             0.117396    721.0  2037.25  2024.40  2011.590  2024.413333
# 13             0.851569    722.5  5212.75  2057.58  1986.875  3085.735000
# 14             0.128605    724.0  2073.50  2090.88  2208.200  2124.193333
# 15             0.119656    717.0  2134.16  2151.00  2272.890  2186.016667
# 16             0.122725    717.0  2281.60  2319.84  2351.760  2317.733333
# 17             0.122890    715.0  2352.35  2356.72  2466.750  2391.940000
# 18             0.004388    709.0  2402.81  2402.81  2495.680  2433.766667
# 19             0.000529    709.0  2459.85  2492.10  2573.670  2508.540000
#
# [20 rows x 34 columns]

# %%
# CV时不方便shuffle，因此准备训练集和测试集时shuffle
# df = df.sample(frac=1).reset_index(drop=True)


# 准备训练集和测试集
train = df[df['is_train']==1]
test = df[df['is_train']==0]
print('训练集数量:'+str(len(train)))
print('测试集数量:'+str(len(test)))


# 准备训练集合输入矩阵和输出矩阵
train_X = train.drop(['y','is_train','I_B_cor','I_C_cor'],axis=1)
train_Y = train['y']

# 准备测试集合输入矩阵
test_X = test.drop(['y','is_train','I_B_cor','I_C_cor'],axis=1)

# 准备测试集合输出矩阵容器
ans=pd.DataFrame()
ans['ID']=test_X['ID']
# Out:
# 训练集数量:8918
# 测试集数量:8363

# %%
regrs_light = [
    xgbt3, gbdt3, forest3, lgb3
]

# %%
# 训练集未shuflle时
stacking_model = SVR(C=100, gamma=0.01, epsilon=0.01)
stacker = Stacker(5, stacking_model, regrs_light)
pred_stack, S_train_data, S_predict_data = stacker.fit_predict(train_X, train_Y, test_X)
# Out:
# 1 Base model: XGBRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 2 Base model: GradientBoostingRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 3 Base model: RandomForestRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 4 Base model: LGBMRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# CV MSE: [0.03820138 0.01411471 0.01500888 0.01062797 0.08564431]
# Stacker AVG MSE: 0.03271945123206558 Stacker AVG Score: 0.860264287075261

# %%
stacking_model = SVR(C=100, gamma=0.01, epsilon=0.01)
stacker = Stacker(5, stacking_model, regrs_light)
pred_stack, S_train_data, S_predict_data = stacker.fit_predict(train_X, train_Y, test_X)
# Out:
# 1 Base model: XGBRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 2 Base model: GradientBoostingRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 3 Base model: RandomForestRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# 4 Base model: LGBMRegressor
# Fit fold 1 ...
# Fit fold 2 ...
# Fit fold 3 ...
# Fit fold 4 ...
# Fit fold 5 ...
# CV MSE: [0.02937148 0.03176862 0.01071031 0.03045894 0.0620819 ]
# Stacker AVG MSE: 0.032878251749318445 Stacker AVG Score: 0.8521156276701483

# %%
 df.head(30)
# Out:
#     ID  board_t  env_t  light_strength  efficiency  efficiency_A  \
# 0    9   -19.33  -17.5              13      198.32        259.11
# 1   10   -19.14  -17.4              34       80.55        106.32
# 2   11   -18.73  -17.3              30       99.90        139.00
# 3   12   -17.54  -17.0              41       82.48        114.86
# 4   13   -16.68  -16.6              50       73.59         97.95
# 5   14   -15.43  -16.6              53       73.98        101.72
# 6   15   -14.60  -16.3              65       64.62         86.86
# 7   16   -14.10  -16.2              76       61.97         77.59
# 8   17   -13.27  -16.2              83       75.36         73.55
# 9   18   -12.41  -16.2              86       76.06         75.89
# 10  19   -11.25  -15.9              96       71.51         70.09
# 11  20   -10.77  -15.8             100       70.04         69.27
# 12  21   -10.77  -15.8             100       72.88         73.35
# 13  22   -10.77  -15.8             100     5699.37      16924.86
# 14  23    -9.12  -15.0             115       66.14         64.56
# 15  24    -8.33  -14.7             122       63.99         62.47
# 16  25    -6.96  -14.5             127       64.87         63.86
# 17  26    -6.46  -14.0             138       61.51         60.49
# 18  27    -5.52  -13.9             142       60.63         59.86
# 19  28    -5.54  -13.6             148       59.96         58.80
# 20  29    -4.98  -13.6             150       61.08         60.34
# 21  30    -4.60  -13.9             159       58.79         58.41
# 22  31    -4.33  -13.8             168       57.14         55.75
# 23  32    -3.96  -13.7             171       57.40         57.01
# 24  33    -3.60  -13.4             181       56.26         55.30
# 25  34    -3.70  -13.4             187       55.68         54.59
# 26  35    -3.79  -13.1             189       55.75         55.28
# 27  36    -3.98  -12.4             194       55.50         54.50
# 28  37    -3.75  -12.7             201       55.22         55.35
# 29  38    -3.06  -12.1             211       53.95         53.15
#
#     efficiency_B  efficiency_C  wind_speed  wind_direction     ...       \
# 0          42.17        293.66         0.3             273     ...
# 1          16.98        118.36         0.6             272     ...
# 2          21.20        139.51         0.8             275     ...
# 3          14.91        117.66         1.1             283     ...
# 4          14.70        108.12         0.9             277     ...
# 5          15.55        104.67         0.9             280     ...
# 6          13.09         93.92         1.1             280     ...
# 7          25.80         82.53         0.9             278     ...
# 8          73.36         79.16         0.7             280     ...
# 9          73.95         78.34         1.0             279     ...
# 10         70.09         74.35         1.5             277     ...
# 11         68.43         72.42         1.5             281     ...
# 12         72.88         72.42         1.5             281     ...
# 13        162.65         10.59         1.5             281     ...
# 14         65.10         68.75         0.9             277     ...
# 15         62.96         66.53         0.7             278     ...
# 16         64.93         65.83         0.9             281     ...
# 17         60.60         63.43         0.0             264     ...
# 18         59.86         62.17         0.0             265     ...
# 19         59.57         61.52         0.0             265     ...
# 20         61.49         61.41         0.0             276     ...
# 21         58.65         59.33         1.2             276     ...
# 22         56.77         58.91         0.7             271     ...
# 23         56.98         58.22         1.3             277     ...
# 24         55.83         57.66         1.7             277     ...
# 25         55.25         57.20         1.8             282     ...
# 26         55.04         56.92         1.8             283     ...
# 27         55.11         56.89         1.2             285     ...
# 28         54.62         55.68         1.0             276     ...
# 29         53.38         55.31         0.9             292     ...
#
#     V_B_avg_sequence  V_B_exception_ratio  V_B_cor  V_C_avg_sequence  \
# 0         715.750000             0.015019    705.0        725.000000
# 1         717.200000             0.011433    709.0        724.400000
# 2         717.833333             0.001161    717.0        724.833333
# 3         718.571429             0.004771    722.0        725.571429
# 4         720.000000             0.006944    715.0        724.250000
# 5         721.500000             0.007623    727.0        725.375000
# 6         723.375000             0.007776    729.0        725.125000
# 7         723.875000             0.005698    728.0        725.000000
# 8         724.625000             0.002243    723.0        725.125000
# 9         635.375000             0.147354    729.0        647.000000
# 10        635.625000             0.142183    726.0        647.000000
# 11        634.875000             0.134082    720.0        646.125000
# 12        633.000000             0.142180    723.0        645.250000
# 13        721.125000             0.990293    724.5        720.875000
# 14        629.250000             0.153754    726.0        641.500000
# 15        628.375000             0.141038    717.0        640.375000
# 16        626.750000             0.142401    716.0        638.625000
# 17        625.250000             0.138745    712.0        636.750000
# 18        712.375000             0.000877    713.0        712.125000
# 19        709.625000             0.000528    710.0        709.375000
# 20        708.375000             0.003353    706.0        707.750000
# 21        706.625000             0.000531    707.0        706.125000
# 22        705.500000             0.000709    705.0        704.250000
# 23        704.375000             0.004791    701.0        703.375000
# 24        702.875000             0.000178    703.0        702.000000
# 25        701.875000             0.001603    703.0        700.750000
# 26        701.125000             0.000178    701.0        699.750000
# 27        699.875000             0.000179    700.0        698.375000
# 28        698.750000             0.001789    700.0        697.375000
# 29        697.375000             0.000896    698.0        696.125000
#
#     V_C_exception_ratio  V_C_cor  P_A_cor  P_B_cor   P_C_cor    P_avg_cor
# 0              0.005517    721.0   909.72   148.05  1031.030   696.266667
# 1              0.000828    725.0   976.86   155.98  1087.500   740.113333
# 2              0.001610    726.0  1128.40   172.08  1132.560   811.013333
# 3              0.007679    720.0  1279.25   166.06  1310.400   918.570000
# 4              0.006559    729.0  1334.07   200.20  1472.580  1002.283333
# 5              0.000862    726.0  1474.60   225.37  1517.340  1072.436667
# 6              0.003965    728.0  1548.51   233.28  1674.400  1152.063333
# 7              0.001379    724.0  1619.93   538.72  1723.120  1293.923333
# 8              0.001551    724.0  1681.68  1677.36  1810.000  1723.013333
# 9              0.123648    727.0  1802.96  1756.89  1861.120  1806.990000
# 10             0.120556    725.0  1865.82  1865.82  1979.250  1903.630000
# 11             0.115883    721.0  1923.90  1900.80  2011.590  1945.430000
# 12             0.117396    721.0  2037.25  2024.40  2011.590  2024.413333
# 13             0.851569    722.5  5212.75  2057.58  1986.875  3085.735000
# 14             0.128605    724.0  2073.50  2090.88  2208.200  2124.193333
# 15             0.119656    717.0  2134.16  2151.00  2272.890  2186.016667
# 16             0.122725    717.0  2281.60  2319.84  2351.760  2317.733333
# 17             0.122890    715.0  2352.35  2356.72  2466.750  2391.940000
# 18             0.004388    709.0  2402.81  2402.81  2495.680  2433.766667
# 19             0.000529    709.0  2459.85  2492.10  2573.670  2508.540000
# 20             0.001060    707.0  2563.10  2612.20  2608.830  2594.710000
# 21             0.003009    704.0  2633.38  2644.18  2675.200  2650.920000
# 22             0.000355    704.0  2658.32  2707.20  2808.960  2724.826667
# 23             0.001955    702.0  2770.65  2768.95  2829.060  2789.553333
# 24             0.000000    702.0  2848.20  2875.27  2969.460  2897.643333
# 25             0.000357    701.0  2903.39  2938.54  3042.340  2961.423333
# 26             0.000357    700.0  2970.88  2958.22  3059.000  2996.033333
# 27             0.002327    700.0  3004.56  3038.00  3136.000  3059.520000
# 28             0.000896    698.0  3164.00  3122.00  3182.880  3156.293333
# 29             0.000180    696.0  3196.56  3210.80  3326.880  3244.746667
#
# [30 rows x 34 columns]
