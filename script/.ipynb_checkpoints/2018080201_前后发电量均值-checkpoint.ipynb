# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import lightgbm

from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

from matplotlib.pyplot import figure

# %matplotlib inline

# %%
rep_cols = {'ID':'ID', 
 '板温':'board_t', 
 '现场温度':'env_t', 
 '光照强度':'light_strength', 
 '转换效率':'efficiency', 
 '转换效率A':'efficiency_A', 
 '转换效率B':'efficiency_B', 
 '转换效率C':'efficiency_C', 
 '电压A':'V_A',
 '电压B':'V_B', 
 '电压C':'V_C', 
 '电流A':'I_A', 
 '电流B':'I_B', 
 '电流C':'I_C', 
 '功率A':'P_A', 
 '功率B':'P_B', 
 '功率C':'P_C', 
 '平均功率':'P_avg', 
 '风速':'wind_speed',
 '风向':'wind_direction', 
 '发电量':'y'
}

# %%
def my_val(preds, train_data):
    label = train_data.get_label()
    return 'score', 1/(1+np.sqrt(mean_squared_error(preds, label))), True
def my_obj(preds, train_data):
    labels = train_deata.get_label()

# %%
train = pd.read_csv('../data/public_raw.train.csv')
test = pd.read_csv('../data/public_raw.test.csv')

train_len = train.shape[0]

train['is_train']=1
test['is_train']=0

df = pd.concat([train, test],sort=False)

# %%
df.rename(index=str, columns=rep_cols, inplace=True)

# %%
df.head()
# Out:
#    ID  board_t  env_t  light_strength  efficiency  efficiency_A  efficiency_B  \
# 0  10   -19.14  -17.4              34       80.55        106.32         16.98
# 1  11   -18.73  -17.3              30       99.90        139.00         21.20
# 2  12   -17.54  -17.0              41       82.48        114.86         14.91
# 3  14   -15.43  -16.6              53       73.98        101.72         15.55
# 4  15   -14.60  -16.3              65       64.62         86.86         13.09
#
#    efficiency_C  V_A  V_B    ...      I_B   I_C      P_A     P_B      P_C  \
# 0        118.36  729  709    ...     0.22  1.50   976.86  155.98  1087.50
# 1        139.51  728  717    ...     0.24  1.56  1128.40  172.08  1132.56
# 2        117.66  731  722    ...     0.23  1.82  1279.25  166.06  1310.40
# 3        104.67  730  727    ...     0.31  2.09  1474.60  225.37  1517.34
# 4         93.92  727  729    ...     0.32  2.30  1548.51  233.28  1674.40
#
#      P_avg  wind_speed  wind_direction         y  is_train
# 0   740.11         0.6             272  1.437752         1
# 1   811.01         0.8             275  1.692575         1
# 2   918.57         1.1             283  1.975787         1
# 3  1072.44         0.9             280  2.370656         1
# 4  1152.06         1.1             280  2.532091         1
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#          ID  board_t  env_t  light_strength  efficiency  efficiency_A  \
# 8404  17869    35.64   24.6             552       21.07         21.71
# 8405  17870    35.89   24.5             801       18.03         18.02
# 8406  17871    36.64   24.7             792       17.90         17.74
# 8407  17872    36.51   24.9             789       17.61         17.62
# 8408  17875    36.31   25.1             752       17.69         17.60
#
#       efficiency_B  efficiency_C  V_A  V_B    ...      I_B   I_C      P_A  \
# 8404         23.81         17.69  599  593    ...     7.28  5.40  3935.43
# 8405         17.72         18.36  593  593    ...     7.87  8.18  4744.00
# 8406         17.92         18.05  591  590    ...     7.93  7.99  4633.44
# 8407         17.52         17.68  592  591    ...     7.71  7.83  4582.08
# 8408         17.55         17.92  592  593    ...     7.33  7.52  4357.12
#
#           P_B      P_C    P_avg  wind_speed  wind_direction   y  is_train
# 8404  4317.04  3207.60  3820.02         3.2             218 NaN         0
# 8405  4666.91  4834.38  4748.43         5.7             272 NaN         0
# 8406  4678.70  4714.10  4675.41         5.4             187 NaN         0
# 8407  4556.61  4596.21  4578.30         6.7             234 NaN         0
# 8408  4346.69  4436.80  4380.20         3.1             250 NaN         0
#
# [5 rows x 22 columns]

# %%
df.sort_values(by=['ID'],ascending=True, inplace=True)

# %%
df.head(30)
# Out:
#     ID  board_t  env_t  light_strength  efficiency  efficiency_A  \
# 0    1     0.01    0.1               1        0.00          0.00
# 1    9   -19.33  -17.5              13      198.32        259.11
# 0   10   -19.14  -17.4              34       80.55        106.32
# 1   11   -18.73  -17.3              30       99.90        139.00
# 2   12   -17.54  -17.0              41       82.48        114.86
# 2   13   -16.68  -16.6              50       73.59         97.95
# 3   14   -15.43  -16.6              53       73.98        101.72
# 4   15   -14.60  -16.3              65       64.62         86.86
# 5   16   -14.10  -16.2              76       61.97         77.59
# 3   17   -13.27  -16.2              83       75.36         73.55
# 4   18   -12.41  -16.2              86       76.06         75.89
# 6   19   -11.25  -15.9              96       71.51         70.09
# 7   20   -10.77  -15.8             100       70.04         69.27
# 5   21   -10.77  -15.8             100       72.88         73.35
# 8   22   -10.77  -15.8             100     5699.37      16924.86
# 6   23    -9.12  -15.0             115       66.14         64.56
# 9   24    -8.33  -14.7             122       63.99         62.47
# 7   25    -6.96  -14.5             127       64.87         63.86
# 8   26    -6.46  -14.0             138       61.51         60.49
# 10  27    -5.52  -13.9             142       60.63         59.86
# 9   28    -5.54  -13.6             148       59.96         58.80
# 10  29    -4.98  -13.6             150       61.08         60.34
# 11  30    -4.60  -13.9             159       58.79         58.41
# 11  31    -4.33  -13.8             168       57.14         55.75
# 12  32    -3.96  -13.7             171       57.40         57.01
# 13  33    -3.60  -13.4             181       56.26         55.30
# 12  34    -3.70  -13.4             187       55.68         54.59
# 13  35    -3.79  -13.1             189       55.75         55.28
# 14  36    -3.98  -12.4             194       55.50         54.50
# 15  37    -3.75  -12.7             201       55.22         55.35
#
#     efficiency_B  efficiency_C    V_A  V_B    ...        I_B   I_C        P_A  \
# 0           0.00          0.00      0    0    ...       0.00  0.00       0.00
# 1          42.17        293.66    722  705    ...       0.21  1.43     909.72
# 0          16.98        118.36    729  709    ...       0.22  1.50     976.86
# 1          21.20        139.51    728  717    ...       0.24  1.56    1128.40
# 2          14.91        117.66    731  722    ...       0.23  1.82    1279.25
# 2          14.70        108.12    729  715    ...       0.28  2.02    1334.07
# 3          15.55        104.67    730  727    ...       0.31  2.09    1474.60
# 4          13.09         93.92    727  729    ...       0.32  2.30    1548.51
# 5          25.80         82.53    733  728    ...       0.74  2.38    1619.93
# 3          73.36         79.16    728  723    ...       2.32  2.50    1681.68
# 4          73.95         78.34    727  729    ...       2.41  2.56    1802.96
# 6          70.09         74.35    726  726    ...       2.57  2.73    1865.82
# 7          68.43         72.42    726  720    ...       2.64  2.79    1923.90
# 5          72.88         72.42    725  723    ...       2.80  2.79    2037.25
# 8         162.65         10.59  65382    7    ...     645.39  2.75  470096.58
# 6          65.10         68.75    725  726    ...       2.88  3.05    2073.50
# 9          62.96         66.53    721  717    ...       3.00  3.17    2134.16
# 7          64.93         65.83    713  716    ...       3.24  3.28    2281.60
# 8          60.60         63.43    715  712    ...       3.31  3.45    2352.35
# 10         59.86         62.17    713  713    ...       3.37  3.52    2402.81
# 9          59.57         61.52    713  710    ...       3.51  3.63    2459.85
# 10         61.49         61.41    710  706    ...       3.70  3.69    2563.10
# 11         58.65         59.33    706  707    ...       3.74  3.80    2633.38
# 11         56.77         58.91    707  705    ...       3.84  3.99    2658.32
# 12         56.98         58.22    705  701    ...       3.95  4.03    2770.65
# 13         55.83         57.66    705  703    ...       4.09  4.23    2848.20
# 12         55.25         57.20    703  703    ...       4.18  4.34    2903.39
# 13         55.04         56.92    704  701    ...       4.22  4.37    2970.88
# 14         55.11         56.89    702  700    ...       4.34  4.48    3004.56
# 15         54.62         55.68    700  700    ...       4.46  4.56    3164.00
#
#         P_B      P_C      P_avg  wind_speed  wind_direction         y  \
# 0      0.00     0.00       0.00         0.1               1       NaN
# 1    148.05  1031.03     696.27         0.3             273       NaN
# 0    155.98  1087.50     740.11         0.6             272  1.437752
# 1    172.08  1132.56     811.01         0.8             275  1.692575
# 2    166.06  1310.40     918.57         1.1             283  1.975787
# 2    200.20  1472.58    1002.28         0.9             277       NaN
# 3    225.37  1517.34    1072.44         0.9             280  2.370656
# 4    233.28  1674.40    1152.06         1.1             280  2.532091
# 5    538.72  1723.12    1293.92         0.9             278  2.779719
# 3   1677.36  1810.00    1723.01         0.7             280       NaN
# 4   1756.89  1861.12    1806.99         1.0             279       NaN
# 6   1865.82  1979.25    1903.63         1.5             277  3.832378
# 7   1900.80  2011.59    1945.43         1.5             281  3.956692
# 5   2024.40  2011.59    2024.41         1.5             281       NaN
# 8   4517.73   294.25  158302.85         1.5             281  5.440741
# 6   2090.88  2208.20    2124.19         0.9             277       NaN
# 9   2151.00  2272.89    2186.02         0.7             278  4.501339
# 7   2319.84  2351.76    2317.73         0.9             281       NaN
# 8   2356.72  2466.75    2391.94         0.0             264       NaN
# 10  2402.81  2495.68    2433.77         0.0             265  5.135805
# 9   2492.10  2573.67    2508.54         0.0             265       NaN
# 10  2612.20  2608.83    2594.71         0.0             276       NaN
# 11  2644.18  2675.20    2650.92         1.2             276  5.632254
# 11  2707.20  2808.96    2724.83         0.7             271       NaN
# 12  2768.95  2829.06    2789.55         1.3             277       NaN
# 13  2875.27  2969.46    2897.64         1.7             277       NaN
# 12  2938.54  3042.34    2961.42         1.8             282  6.240380
# 13  2958.22  3059.00    2996.03         1.8             283  6.325290
# 14  3038.00  3136.00    3059.52         1.2             285       NaN
# 15  3122.00  3182.88    3156.29         1.0             276       NaN
#
#     is_train
# 0          0
# 1          0
# 0          1
# 1          1
# 2          1
# 2          0
# 3          1
# 4          1
# 5          1
# 3          0
# 4          0
# 6          1
# 7          1
# 5          0
# 8          1
# 6          0
# 9          1
# 7          0
# 8          0
# 10         1
# 9          0
# 10         0
# 11         1
# 11         0
# 12         0
# 13         0
# 12         1
# 13         1
# 14         0
# 15         0
#
# [30 rows x 22 columns]

# %%
light_id=df.head(1000)

figure(num=None, figsize=(14, 6), dpi=100, facecolor='w', edgecolor='k')

ax = plt.gca()

light_id.plot(x='ID',y='light_strength',color='yellow',ax=ax)
light_id.plot(x='ID',y='y',secondary_y=True,color='red',ax=ax)

plt.show()

# %%
t_id=df.head(1000)

figure(num=None, figsize=(14, 6), dpi=100, facecolor='w', edgecolor='k')

ax = plt.gca()

light_id.plot(x='ID',y='board_t',color='green',ax=ax)
light_id.plot(x='ID',y='y',secondary_y=True,color='red',ax=ax)

plt.show()

# %%
df.sort_values(by=['ID'],ascending=True, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
#此做法不妥，因为原始数据中存在发电量为负数
df['y']=df['y'].fillna(-999)

# %%
next_one = []
prev_one = []
next_id = []
prev_id = []
next_b_t = []
prev_b_t = []
next_t = []
prev_t = []
next_ls = []
prev_ls = []

df_len = df.shape[0]

i_y =df.columns.get_loc("y")
i_ls = df.columns.get_loc("light_strength")

for i in range(df_len):
    prev = i-1
    while(prev>=0 and df.iat[prev,i_y]<0):
        prev-=1
    if prev>=0:
        prev_one.append(df.iat[prev,i_y])
        prev_id.append(prev)
        prev_ls.append(df.iat[prev,i_ls])
    else:
        prev_one.append(np.nan)
        prev_id.append(0)
        prev_ls.append(0)
        
    next = i+1
    while(next<df_len and df.iat[next,i_y]<0):
        next+=1
    if next<df_len:
        next_one.append(df.iat[next,i_y])
        next_id.append(next)
        next_ls.append(df.iat[next,i_ls])
    else:
        next_one.append(np.nan)
        next_id.append(df_len)
        next_ls.append(0)

# %%
df['next_value'] = next_one
df['prev_value'] = prev_one
df['avg_value'] = np.nanmean([df['next_value'], df['prev_value']],axis=0)
df['next_ID'] = next_id
df['prev_ID'] = prev_id
df['next_ls'] = next_ls
df['prev_ls'] = prev_ls
df['interpolation_ID'] = df['prev_value']+(df['ID']-df['prev_ID'])/(df['next_ID']-df['prev_ID'])*(df['next_value']-df['prev_value'])
df['interpolation_ls'] = df['prev_value']+(df['light_strength']-df['prev_ls'])/(1+df['next_ls']-df['prev_ls'])*(df['next_value']-df['prev_value'])

# %%
df['magic_feature'] = df['ID']%190

# %%
df[['ID','y','avg_value','interpolation_ID','interpolation_ls']].head(40)
# Out:
#     ID           y  avg_value  interpolation_ID  interpolation_ls
# 0    1 -999.000000   1.437752               NaN               NaN
# 1    9 -999.000000   1.437752               NaN               NaN
# 2   10    1.437752   1.692575               NaN               NaN
# 3   11    1.692575   1.706770          3.858913          1.168734
# 4   12    1.975787   2.031615          3.726817          2.003362
# 5   13 -999.000000   2.173222          3.752694          2.249158
# 6   14    2.370656   2.253939          3.830134          2.242813
# 7   15    2.532091   2.575187          4.211441          2.575187
# 8   16    2.779719   3.182235          5.457736          2.979065
# 9   17 -999.000000   3.306048          5.937696          3.130605
# 10  18 -999.000000   3.306048          6.288582          3.280985
# 11  19    3.832378   3.368205          6.016394          3.721297
# 12  20    3.956692   4.636559          8.657466          5.119068
# 13  21 -999.000000   4.698716         10.634911          3.956692
# 14  22    5.440741   4.229016          5.318310          3.956692
# 15  23 -999.000000   4.971040          1.213435          4.828087
# 16  24    4.501339   5.288273          4.830870          5.284727
# 17  25 -999.000000   4.818572          6.404738          4.652403
# 18  26 -999.000000   4.818572          6.616226          4.984742
# 19  27    5.135805   5.066796          6.574682          5.096557
# 20  28 -999.000000   5.384029          6.625150          5.301288
# 21  29 -999.000000   5.384029          6.790633          5.356449
# 22  30    5.632254   5.688093          6.871565          5.544018
# 23  31 -999.000000   5.936317          7.000538          5.820982
# 24  32 -999.000000   5.936317          7.152569          5.883892
# 25  33 -999.000000   5.936317          7.304601          6.093591
# 26  34    6.240380   5.978772          7.295541          6.258222
# 27  35    6.325290   6.566919          7.415922          6.288756
# 28  36 -999.000000   6.609374          7.603670          6.438924
# 29  37 -999.000000   6.609374          7.745712          6.598011
# 30  38 -999.000000   6.609374          7.887754          6.825279
# 31  39    6.893459   6.759761          7.814905          6.833939
# 32  40 -999.000000   7.043845          7.795779          6.981921
# 33  41 -999.000000   7.043845          7.896036          7.088077
# 34  42    7.194232   7.151363          8.311930          7.286455
# 35  43    7.409266   7.340494          8.510591          7.272238
# 36  44    7.486756   7.466886          7.927845          7.497912
# 37  45    7.524506   7.607116          8.208915          7.546936
# 38  46 -999.000000   7.625991          8.437870          7.592163
# 39  47    7.727476   7.691939          8.361672          7.617525

# %%
inter_y_id=df.head(2000)

figure(num=None, figsize=(14, 6), dpi=100, facecolor='w', edgecolor='k')

ax = plt.gca()

inter_y_id.plot(x='ID',y='avg_value',ax=ax)
inter_y_id.plot(x='ID',y='y',ylim=(-1,14),ax=ax)

plt.show()

# %%
df.avg_value.describe()
# Out:
# count    17409.000000
# mean         5.690951
# std          3.431096
# min          0.008512
# 25%          2.511387
# 50%          5.710151
# 75%          8.842590
# max         12.227251
# Name: avg_value, dtype: float64

# %%
train = df[df['is_train']==1]
test = df[df['is_train']==0]

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression_l2',
    'metric': 'mse',
    'num_leaves': 31,
    'learning_rate': 0.08,
    'feature_fraction': 0.6,
    'bagging_fraction': 0.8,
    'bagging_freq': 1,
    'verbose': 0
}

predictor = [c for c in train.columns.tolist() if c not in['y','is_train']]

test_predicts = []
val_preds = []

# log_test_predicts = []
# log_val_predicts = []
for idx, seed in enumerate([1,2,3,4,5]):
    kf = KFold(5, shuffle=True, random_state=seed)
    
    val_preds.append(np.zeros(train.shape[0]))
    for n_fold, (tra_idx, val_idx) in enumerate(kf.split(train)):
        tra = train.iloc[tra_idx]
        val = train.iloc[val_idx]

        train_set = lightgbm.Dataset(
            tra[predictor],
            tra['y']
        )

        validation_set = lightgbm.Dataset(
            val[predictor],
            val['y']
        )

        model = lightgbm.train(params, train_set, num_boost_round=5000,
                              valid_sets= [validation_set],
                              valid_names=['valid'],
                              early_stopping_rounds=100,
                               feval=my_val,
                              verbose_eval=500)

        val_preds[idx][val_idx] = model.predict(val[predictor])
        test_predicts.append(model.predict(test[predictor]))

print('local cv:',1/(1+np.sqrt(mean_squared_error(train['y'],np.mean(val_preds,axis=0)))))
# Out:
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0561782	valid's score: 0.808395
# Early stopping, best iteration is:
# [622]	valid's l2: 0.056137	valid's score: 0.808452
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0184037	valid's score: 0.880545
# Early stopping, best iteration is:
# [606]	valid's l2: 0.0182689	valid's score: 0.880931
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [172]	valid's l2: 0.0131367	valid's score: 0.89717
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0407441	valid's score: 0.832049
# [1000]	valid's l2: 0.039119	valid's score: 0.834874
# [1500]	valid's l2: 0.0387643	valid's score: 0.835501
# Early stopping, best iteration is:
# [1730]	valid's l2: 0.0387178	valid's score: 0.835583
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [213]	valid's l2: 0.0162736	valid's score: 0.886865
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0609449	valid's score: 0.802008
# [1000]	valid's l2: 0.0596192	valid's score: 0.803748
# [1500]	valid's l2: 0.0593808	valid's score: 0.804064
# Early stopping, best iteration is:
# [1565]	valid's l2: 0.0593694	valid's score: 0.804079
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0154914	valid's score: 0.889312
# Early stopping, best iteration is:
# [592]	valid's l2: 0.0152952	valid's score: 0.889938
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [137]	valid's l2: 0.0239158	valid's score: 0.866065
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0252849	valid's score: 0.862804
# Early stopping, best iteration is:
# [551]	valid's l2: 0.0251559	valid's score: 0.863106
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0145337	valid's score: 0.892414
# Early stopping, best iteration is:
# [832]	valid's l2: 0.0143745	valid's score: 0.892942
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0318527	valid's score: 0.848555
# Early stopping, best iteration is:
# [646]	valid's l2: 0.0316177	valid's score: 0.849031
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0549963	valid's score: 0.810036
# [1000]	valid's l2: 0.0544119	valid's score: 0.810857
# Early stopping, best iteration is:
# [1144]	valid's l2: 0.0543515	valid's score: 0.810942
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [207]	valid's l2: 0.0165104	valid's score: 0.886138
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.013397	valid's score: 0.896262
# Early stopping, best iteration is:
# [662]	valid's l2: 0.0132234	valid's score: 0.896867
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0288727	valid's score: 0.854759
# [1000]	valid's l2: 0.028335	valid's score: 0.855922
# Early stopping, best iteration is:
# [1020]	valid's l2: 0.0283187	valid's score: 0.855958
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0182608	valid's score: 0.880955
# Early stopping, best iteration is:
# [435]	valid's l2: 0.018202	valid's score: 0.881124
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [236]	valid's l2: 0.0521865	valid's score: 0.814038
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [396]	valid's l2: 0.0284061	valid's score: 0.855768
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0292243	valid's score: 0.854007
# [1000]	valid's l2: 0.0282554	valid's score: 0.856096
# Early stopping, best iteration is:
# [1177]	valid's l2: 0.0281462	valid's score: 0.856334
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [354]	valid's l2: 0.0233389	valid's score: 0.867475
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [218]	valid's l2: 0.0148914	valid's score: 0.891241
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0845488	valid's score: 0.77473
# [1000]	valid's l2: 0.0779247	valid's score: 0.781769
# [1500]	valid's l2: 0.075808	valid's score: 0.784109
# [2000]	valid's l2: 0.0749413	valid's score: 0.785081
# [2500]	valid's l2: 0.0746406	valid's score: 0.78542
# [3000]	valid's l2: 0.0745869	valid's score: 0.785481
# Early stopping, best iteration is:
# [3021]	valid's l2: 0.0745813	valid's score: 0.785487
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [153]	valid's l2: 0.0166532	valid's score: 0.885703
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [183]	valid's l2: 0.0206173	valid's score: 0.874441
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [124]	valid's l2: 0.0223889	valid's score: 0.869846
# local cv: 0.8600680346985461

# %%
pd.Series(model.feature_importance(importance_type='gain'),
          index=model.feature_name()).sort_values(ascending=False).head(40)
# Out:
# P_A                 213149.607026
# I_A                  78529.501081
# I_C                  56092.202971
# P_avg                42472.512904
# avg_value            19700.462062
# P_C                  18021.842621
# P_B                  11941.301616
# I_B                   7474.480137
# prev_value            1379.436493
# interpolation_ls       361.001004
# light_strength         187.626057
# next_value             145.070258
# efficiency_C           123.407627
# V_B                    111.922425
# board_t                109.518282
# wind_direction          96.002370
# efficiency              89.879717
# prev_ls                 81.411088
# V_A                     76.019131
# next_ls                 64.085769
# wind_speed              60.956039
# efficiency_B            40.054368
# V_C                     39.661732
# env_t                   38.248736
# efficiency_A            30.321828
# magic_feature           24.418665
# ID                      23.319929
# interpolation_ID        19.547515
# next_ID                 18.438956
# prev_ID                  5.659389
# dtype: float64

# %%
train.head(10)
# Out:
#     ID  board_t  env_t  light_strength  efficiency  efficiency_A  \
# 2   10   -19.14  -17.4              34       80.55        106.32
# 3   11   -18.73  -17.3              30       99.90        139.00
# 4   12   -17.54  -17.0              41       82.48        114.86
# 6   14   -15.43  -16.6              53       73.98        101.72
# 7   15   -14.60  -16.3              65       64.62         86.86
# 8   16   -14.10  -16.2              76       61.97         77.59
# 11  19   -11.25  -15.9              96       71.51         70.09
# 12  20   -10.77  -15.8             100       70.04         69.27
# 14  22   -10.77  -15.8             100     5699.37      16924.86
# 16  24    -8.33  -14.7             122       63.99         62.47
#
#     efficiency_B  efficiency_C    V_A  V_B      ...        next_value  \
# 2          16.98        118.36    729  709      ...          1.692575
# 3          21.20        139.51    728  717      ...          1.975787
# 4          14.91        117.66    731  722      ...          2.370656
# 6          15.55        104.67    730  727      ...          2.532091
# 7          13.09         93.92    727  729      ...          2.779719
# 8          25.80         82.53    733  728      ...          3.832378
# 11         70.09         74.35    726  726      ...          3.956692
# 12         68.43         72.42    726  720      ...          5.440741
# 14        162.65         10.59  65382    7      ...          4.501339
# 16         62.96         66.53    721  717      ...          5.135805
#
#     prev_value  avg_value  next_ID  prev_ID  next_ls  prev_ls  \
# 2          NaN   1.692575        3        0       30        0
# 3     1.437752   1.706770        4        2       41       34
# 4     1.692575   2.031615        6        3       53       30
# 6     1.975787   2.253939        7        4       65       41
# 7     2.370656   2.575187        8        6       76       53
# 8     2.532091   3.182235       11        7       96       65
# 11    2.779719   3.368205       12        8      100       76
# 12    3.832378   4.636559       14       11      100       96
# 14    3.956692   4.229016       16       12      122      100
# 16    5.440741   5.288273       19       14      142      100
#
#     interpolation_ID  interpolation_ls  magic_feature
# 2                NaN               NaN             10
# 3           3.858913          1.168734             11
# 4           3.726817          2.003362             12
# 6           3.830134          2.242813             14
# 7           4.211441          2.575187             15
# 8           5.457736          2.979065             16
# 11          6.016394          3.721297             19
# 12          8.657466          5.119068             20
# 14          5.318310          3.956692             22
# 16          4.830870          5.284727             24
#
# [10 rows x 32 columns]

# %%
test['ans'] = np.mean(test_predicts, axis=0)
# Out:
# C:\Users\Alex\Anaconda3\envs\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test[['ID','ans']].to_csv('../result/080201.csv',header=False, index=False)

# %%
test.interpolation_ls.describe()
# Out:
# count    8385.000000
# mean             NaN
# std              NaN
# min             -inf
# 25%         2.389185
# 50%         5.681035
# 75%         8.873646
# max              inf
# Name: interpolation_ls, dtype: float64
