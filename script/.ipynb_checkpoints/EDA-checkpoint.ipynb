# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train = pd.read_csv('../data/public.train.csv')

# %%
train.head()
# Out:
#    ID     板温  现场温度  光照强度   转换效率   转换效率A  转换效率B   转换效率C  电压A  电压B    ...     \
# 0  10 -19.14 -17.4    34  80.55  106.32  16.98  118.36  729  709    ...
# 1  11 -18.73 -17.3    30  99.90  139.00  21.20  139.51  728  717    ...
# 2  12 -17.54 -17.0    41  82.48  114.86  14.91  117.66  731  722    ...
# 3  14 -15.43 -16.6    53  73.98  101.72  15.55  104.67  730  727    ...
# 4  15 -14.60 -16.3    65  64.62   86.86  13.09   93.92  727  729    ...
#
#     电流A   电流B   电流C      功率A     功率B      功率C     平均功率   风速   风向       发电量
# 0  1.34  0.22  1.50   976.86  155.98  1087.50   740.11  0.6  272  1.437752
# 1  1.55  0.24  1.56  1128.40  172.08  1132.56   811.01  0.8  275  1.692575
# 2  1.75  0.23  1.82  1279.25  166.06  1310.40   918.57  1.1  283  1.975787
# 3  2.02  0.31  2.09  1474.60  225.37  1517.34  1072.44  0.9  280  2.370656
# 4  2.13  0.32  2.30  1548.51  233.28  1674.40  1152.06  1.1  280  2.532091
#
# [5 rows x 21 columns]

# %%
train.shape
# Out:
# (9000, 21)

# %%
train.columns
# Out:
# Index(['ID', '板温', '现场温度', '光照强度', '转换效率', '转换效率A', '转换效率B', '转换效率C', '电压A',
#        '电压B', '电压C', '电流A', '电流B', '电流C', '功率A', '功率B', '功率C', '平均功率', '风速',
#        '风向', '发电量'],
#       dtype='object')

# %%
train['发电量'].hist()

# %% [raw]
# 发电量不是一个正态分布

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.matshow(train.corr())

# %%
pd.plotting.scatter_matrix(train[['板温','光照强度','电流A','发电量']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12a6f9208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a744588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a796dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a529cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12a856eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a856be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a906f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a5a9b38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12a9b69e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12aa5c9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a64be10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ac1ef28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12ac013c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12abd8438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ad47b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ad93278>]], dtype=object)

# %% [raw]
# 原始特征里的重要特征已经比较清楚
