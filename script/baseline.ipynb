# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import lightgbm

from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %%
rep_cols = {'ID':'ID', 
 '板温':'board_t', 
 '现场温度':'env_t', 
 '光照强度':'light_strength', 
 '转换效率':'efficiency', 
 '转换效率A':'efficiency_A', 
 '转换效率B':'efficiency_B', 
 '转换效率C':'efficiency_C', 
 '电压A':'V_A',
 '电压B':'V_B', 
 '电压C':'V_C', 
 '电流A':'I_A', 
 '电流B':'I_B', 
 '电流C':'I_C', 
 '功率A':'P_A', 
 '功率B':'P_B', 
 '功率C':'P_C', 
 '平均功率':'P_avg', 
 '风速':'wind_speed',
 '风向':'wind_direction', 
 '发电量':'y'
}

# %%
def my_val(preds, train_data):
    label = train_data.get_label()
    return 'score', 1/(1+np.sqrt(mean_squared_error(preds, label))), True

# %%
def my_obj(preds, train_data):
    labels = train_deata.get_label()

# %%
train = pd.read_csv('../data/public.train.csv')
test = pd.read_csv('../data/public.test.csv')

train_len = train.shape[0]

df = pd.concat([train, test])

# %%
df.rename(index=str, columns=rep_cols, inplace=True)

# %%
df.head()
# Out:
#    ID  light_strength      P_A     P_B      P_C         y    P_avg  board_t  \
# 0  10              34   976.86  155.98  1087.50  1.437752   740.11   -19.14
# 1  11              30  1128.40  172.08  1132.56  1.692575   811.01   -18.73
# 2  12              41  1279.25  166.06  1310.40  1.975787   918.57   -17.54
# 3  14              53  1474.60  225.37  1517.34  2.370656  1072.44   -15.43
# 4  15              65  1548.51  233.28  1674.40  2.532091  1152.06   -14.60
#
#    env_t  V_A     ...      V_C   I_A   I_B   I_C  efficiency  efficiency_A  \
# 0  -17.4  729     ...      725  1.34  0.22  1.50       80.55        106.32
# 1  -17.3  728     ...      726  1.55  0.24  1.56       99.90        139.00
# 2  -17.0  731     ...      720  1.75  0.23  1.82       82.48        114.86
# 3  -16.6  730     ...      726  2.02  0.31  2.09       73.98        101.72
# 4  -16.3  727     ...      728  2.13  0.32  2.30       64.62         86.86
#
#    efficiency_B  efficiency_C  wind_direction  wind_speed
# 0         16.98        118.36             272         0.6
# 1         21.20        139.51             275         0.8
# 2         14.91        117.66             283         1.1
# 3         15.55        104.67             280         0.9
# 4         13.09         93.92             280         1.1
#
# [5 rows x 21 columns]

# %%
#异常值处理
cols = [c for c in df.columns.tolist() if c!='y' and c!='ID']
for c in cols:
    df[c+'_is_out_of_upper'] = (df[c]>df[c].quantile(0.99)).astype(np.int32)
    df[c+'_is_out_of_lower'] = (df[c]<df[c].quantile(0.01)).astype(np.int32)
    df[c] = np.clip(df[c],df[c].quantile(0.01),df[c].quantile(0.99))

# %%
target = ['P_A','P_avg','I_A','P_C','I_C','P_B','I_B']

for c in target:
    df['log_'+c] = np.log1p(df[c])

# %%
# 第一阶，用其他值预测某些特征

params_layer1 = {
    'boosting_type': 'gbdt',
    'objective': 'regression_l1',
    'metric': 'mae',
    'num_leaves': 48,
    'learning_rate': 0.2,
    'feature_fraction': 0.7,
    'bagging_fraction': 0.8,
    'bagging_freq': 1,
    'verbose': 0
}
kf_layer1 = KFold(5, shuffle=True, random_state=1991)

layer1_result = df[['ID']]

for t in target:
    print('Now, we are processing',t)
    # 特征中去掉t
    predictor_t = [c for c in df.columns.tolist() if c not in['ID','y',t,t+'_is_out_of_upper',t+'_is_out_of_lower']]
    
    # 初始化结果
    val_preds = np.zeros(df.shape[0])
    
    for n_fold, (tra_idx, val_idx) in enumerate(kf_layer1.split(df)):
        tra = df.iloc[tra_idx]
        # 删掉有问题的数据
        tra.drop(tra[(tra[t+'_is_out_of_upper']==1)|(tra[t+'_is_out_of_lower']==1)].index, inplace=True)
        
        val = df.iloc[val_idx]
        # 删掉有问题的数据
        val_c = val.drop(val[(val[t+'_is_out_of_upper']==1)|(val[t+'_is_out_of_lower']==1)].index)

        train_set = lightgbm.Dataset(
            tra[predictor_t],
            tra[t]
        )

        validation_set = lightgbm.Dataset(
            val_c[predictor_t],
            val_c[t]
        )

        model = lightgbm.train(params_layer1, train_set, 
                               num_boost_round=8000,
                              valid_sets= [validation_set],
                              valid_names=['valid'],
                              early_stopping_rounds=100,
                              verbose_eval=1000)

        val_preds[val_idx] = model.predict(val[predictor_t])
        
    # 将结果保存起来
    layer1_result['predicted_'+t] = val_preds
# Out:
# Now, we are processing P_A
# Training until validation scores don't improve for 100 rounds.
# /Users/yuanhao/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# [1000]	valid's l1: 19.5699
# [2000]	valid's l1: 19.1661
# [3000]	valid's l1: 18.9809
# [4000]	valid's l1: 18.881
# [5000]	valid's l1: 18.7997
# Early stopping, best iteration is:
# [5861]	valid's l1: 18.7601
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 22.412
# [2000]	valid's l1: 21.6915
# [3000]	valid's l1: 21.4276
# [4000]	valid's l1: 20.9447
# [5000]	valid's l1: 20.7911
# [6000]	valid's l1: 20.6377
# Early stopping, best iteration is:
# [5903]	valid's l1: 20.6355
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 21.9198
# [2000]	valid's l1: 21.2014
# [3000]	valid's l1: 20.8011
# Early stopping, best iteration is:
# [3312]	valid's l1: 20.7189
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 20.8502
# [2000]	valid's l1: 20.4632
# [3000]	valid's l1: 20.2324
# Early stopping, best iteration is:
# [3536]	valid's l1: 20.121
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 21.3021
# [2000]	valid's l1: 20.7647
# [3000]	valid's l1: 20.4697
# Early stopping, best iteration is:
# [3728]	valid's l1: 20.2483
# /Users/yuanhao/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Now, we are processing P_avg
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 14.0323
# [2000]	valid's l1: 13.6525
# [3000]	valid's l1: 13.5146
# Early stopping, best iteration is:
# [3673]	valid's l1: 13.464
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 13.2075
# [2000]	valid's l1: 12.9191
# Early stopping, best iteration is:
# [2846]	valid's l1: 12.7925
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 13.6669
# [2000]	valid's l1: 13.2924
# [3000]	valid's l1: 13.0858
# [4000]	valid's l1: 13.0194
# [5000]	valid's l1: 12.975
# Early stopping, best iteration is:
# [5375]	valid's l1: 12.9535
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 14.6364
# [2000]	valid's l1: 14.3162
# [3000]	valid's l1: 14.1967
# Early stopping, best iteration is:
# [3760]	valid's l1: 14.1098
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 13.7579
# [2000]	valid's l1: 13.1464
# [3000]	valid's l1: 12.9963
# Early stopping, best iteration is:
# [2989]	valid's l1: 12.9949
# Now, we are processing I_A
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0375118
# [2000]	valid's l1: 0.0366067
# [3000]	valid's l1: 0.0361893
# [4000]	valid's l1: 0.0359137
# [5000]	valid's l1: 0.035723
# [6000]	valid's l1: 0.0356051
# Early stopping, best iteration is:
# [6737]	valid's l1: 0.0355325
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0372749
# [2000]	valid's l1: 0.036106
# [3000]	valid's l1: 0.0355907
# Early stopping, best iteration is:
# [3508]	valid's l1: 0.0354072
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0419269
# [2000]	valid's l1: 0.0410642
# [3000]	valid's l1: 0.0405494
# [4000]	valid's l1: 0.0403492
# [5000]	valid's l1: 0.0402124
# [6000]	valid's l1: 0.0400883
# [7000]	valid's l1: 0.0399905
# Early stopping, best iteration is:
# [7173]	valid's l1: 0.0399661
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0359015
# [2000]	valid's l1: 0.0351034
# [3000]	valid's l1: 0.0347926
# [4000]	valid's l1: 0.0344931
# [5000]	valid's l1: 0.0343312
# [6000]	valid's l1: 0.0342441
# Early stopping, best iteration is:
# [6135]	valid's l1: 0.0342204
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0394316
# [2000]	valid's l1: 0.038569
# [3000]	valid's l1: 0.0381941
# [4000]	valid's l1: 0.0379457
# [5000]	valid's l1: 0.0377378
# Early stopping, best iteration is:
# [5562]	valid's l1: 0.0376577
# Now, we are processing P_C
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 24.2909
# [2000]	valid's l1: 23.6639
# [3000]	valid's l1: 23.4207
# [4000]	valid's l1: 23.2992
# Early stopping, best iteration is:
# [4400]	valid's l1: 23.2521
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 24.4489
# [2000]	valid's l1: 23.9951
# Early stopping, best iteration is:
# [2859]	valid's l1: 23.8111
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 22.2535
# [2000]	valid's l1: 21.7624
# Early stopping, best iteration is:
# [2432]	valid's l1: 21.6468
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 22.4619
# [2000]	valid's l1: 21.9369
# [3000]	valid's l1: 21.7258
# [4000]	valid's l1: 21.5664
# Early stopping, best iteration is:
# [4169]	valid's l1: 21.5448
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 24.411
# [2000]	valid's l1: 23.7804
# [3000]	valid's l1: 23.5041
# [4000]	valid's l1: 23.339
# Early stopping, best iteration is:
# [4276]	valid's l1: 23.2681
# Now, we are processing I_C
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0358172
# [2000]	valid's l1: 0.035182
# [3000]	valid's l1: 0.0349617
# [4000]	valid's l1: 0.0347338
# Early stopping, best iteration is:
# [4453]	valid's l1: 0.0346744
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0379921
# [2000]	valid's l1: 0.0371783
# [3000]	valid's l1: 0.0367086
# [4000]	valid's l1: 0.0364767
# Early stopping, best iteration is:
# [4622]	valid's l1: 0.0363988
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0362773
# [2000]	valid's l1: 0.0356223
# [3000]	valid's l1: 0.0353733
# [4000]	valid's l1: 0.0351769
# [5000]	valid's l1: 0.0350613
# [6000]	valid's l1: 0.0349792
# Early stopping, best iteration is:
# [5935]	valid's l1: 0.0349784
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0363567
# [2000]	valid's l1: 0.0354809
# [3000]	valid's l1: 0.035173
# Early stopping, best iteration is:
# [3327]	valid's l1: 0.0351166
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0384129
# [2000]	valid's l1: 0.037529
# Early stopping, best iteration is:
# [2612]	valid's l1: 0.0372513
# Now, we are processing P_B
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 22.9025
# [2000]	valid's l1: 22.431
# [3000]	valid's l1: 22.2404
# Early stopping, best iteration is:
# [3080]	valid's l1: 22.2202
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 26.0144
# [2000]	valid's l1: 25.1605
# [3000]	valid's l1: 24.7884
# [4000]	valid's l1: 24.5805
# [5000]	valid's l1: 24.4945
# [6000]	valid's l1: 24.3628
# [7000]	valid's l1: 24.2604
# [8000]	valid's l1: 24.213
# Did not meet early stopping. Best iteration is:
# [7999]	valid's l1: 24.2127
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 22.9642
# [2000]	valid's l1: 22.3875
# Early stopping, best iteration is:
# [2476]	valid's l1: 22.2566
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 24.331
# [2000]	valid's l1: 23.8125
# [3000]	valid's l1: 23.4597
# [4000]	valid's l1: 23.2701
# [5000]	valid's l1: 23.1705
# [6000]	valid's l1: 23.0777
# Early stopping, best iteration is:
# [6536]	valid's l1: 23.0481
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 27.6436
# [2000]	valid's l1: 26.9153
# [3000]	valid's l1: 26.531
# [4000]	valid's l1: 26.3793
# Early stopping, best iteration is:
# [4440]	valid's l1: 26.2304
# Now, we are processing I_B
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0397971
# [2000]	valid's l1: 0.0391226
# [3000]	valid's l1: 0.0388667
# [4000]	valid's l1: 0.0387147
# [5000]	valid's l1: 0.038575
# Early stopping, best iteration is:
# [5047]	valid's l1: 0.0385707
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0439013
# [2000]	valid's l1: 0.0425528
# [3000]	valid's l1: 0.0418306
# Early stopping, best iteration is:
# [3356]	valid's l1: 0.041716
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0421433
# [2000]	valid's l1: 0.0411946
# [3000]	valid's l1: 0.0408996
# [4000]	valid's l1: 0.0406536
# Early stopping, best iteration is:
# [4164]	valid's l1: 0.0405979
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0419733
# [2000]	valid's l1: 0.0407768
# [3000]	valid's l1: 0.0402359
# [4000]	valid's l1: 0.0399118
# Early stopping, best iteration is:
# [4427]	valid's l1: 0.0398463
# Training until validation scores don't improve for 100 rounds.
# [1000]	valid's l1: 0.0445693
# [2000]	valid's l1: 0.0434493
# [3000]	valid's l1: 0.0428708
# [4000]	valid's l1: 0.0426029
# [5000]	valid's l1: 0.0424006
# [6000]	valid's l1: 0.0422372
# [7000]	valid's l1: 0.042051
# [8000]	valid's l1: 0.0419301
# Did not meet early stopping. Best iteration is:
# [7984]	valid's l1: 0.0419296

# %%
layer1_result.head()
# Out:
#    ID  predicted_P_A  predicted_P_avg  predicted_I_A  predicted_P_C  \
# 0  10     966.992700       745.956065       1.378123    1105.887180
# 1  11    1143.933980       791.085711       1.506057    1160.905395
# 2  12    1268.876903       908.922733       1.792034    1316.487492
# 3  14    1488.137080      1056.086816       2.016126    1552.175131
# 4  15    1540.428434      1167.471279       2.061485    1678.449627
#
#    predicted_I_C  predicted_P_B  predicted_I_B
# 0       1.519377     112.660774       0.261436
# 1       1.611262     158.551712       0.234952
# 2       1.886203     147.423895       0.191875
# 3       2.096158     245.038840       0.339960
# 4       2.283592     191.410674       0.265982

# %%
layer1_result.to_pickle('../feature/predicted_value.pkl')

# %%
layer1_result = pd.read_pickle('../feature/predicted_value.pkl')

# %%
df = df.merge(layer1_result, on='ID', how='left')

# %%
for t in target:
    df['diff_'+t] = df[t]-df['predicted_'+t]

# %%
train = df.iloc[0:train_len]
test = df.iloc[train_len:]

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression_l2',
    'metric': 'mse',
    'num_leaves': 31,
    'learning_rate': 0.08,
    'feature_fraction': 0.6,
    'bagging_fraction': 0.8,
    'bagging_freq': 1,
    'verbose': 0
}

# %%
predictor = [c for c in train.columns.tolist() if c not in['ID','y']]

# %%
test_predicts = []
val_preds = []
for idx, seed in enumerate([1,2,3,4,5]):
    kf = KFold(5, shuffle=True, random_state=seed)
    
    val_preds.append(np.zeros(train.shape[0]))
    for n_fold, (tra_idx, val_idx) in enumerate(kf.split(train)):
        tra = train.iloc[tra_idx]
        val = train.iloc[val_idx]

        train_set = lightgbm.Dataset(
            tra[predictor],
            tra['y']
        )

        validation_set = lightgbm.Dataset(
            val[predictor],
            val['y']
        )

        model = lightgbm.train(params, train_set, num_boost_round=5000,
                              valid_sets= [validation_set],
                              valid_names=['valid'],
                              early_stopping_rounds=100,
                               feval=my_val,
                              verbose_eval=500)

        val_preds[idx][val_idx] = model.predict(val[predictor])
        test_predicts.append(model.predict(test[predictor]))
# Out:
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0594366	valid's score: 0.80399
# Early stopping, best iteration is:
# [426]	valid's l2: 0.0593033	valid's score: 0.804167
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0226903	valid's score: 0.869087
# [1000]	valid's l2: 0.0192116	valid's score: 0.878267
# [1500]	valid's l2: 0.0186703	valid's score: 0.879786
# Early stopping, best iteration is:
# [1481]	valid's l2: 0.0186448	valid's score: 0.879859
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [114]	valid's l2: 0.013582	valid's score: 0.895623
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0530051	valid's score: 0.812857
# [1000]	valid's l2: 0.0505087	valid's score: 0.816499
# [1500]	valid's l2: 0.0501073	valid's score: 0.817096
# Early stopping, best iteration is:
# [1524]	valid's l2: 0.0500525	valid's score: 0.817178
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0188043	valid's score: 0.879408
# [1000]	valid's l2: 0.0180499	valid's score: 0.881562
# Early stopping, best iteration is:
# [954]	valid's l2: 0.018015	valid's score: 0.881663
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.070482	valid's score: 0.790211
# [1000]	valid's l2: 0.0677959	valid's score: 0.793414
# [1500]	valid's l2: 0.066463	valid's score: 0.795036
# [2000]	valid's l2: 0.0659585	valid's score: 0.795656
# [2500]	valid's l2: 0.0658081	valid's score: 0.795842
# [3000]	valid's l2: 0.0657626	valid's score: 0.795898
# Early stopping, best iteration is:
# [2916]	valid's l2: 0.0657562	valid's score: 0.795906
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0173503	valid's score: 0.88361
# Early stopping, best iteration is:
# [581]	valid's l2: 0.0170587	valid's score: 0.884479
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [183]	valid's l2: 0.0233544	valid's score: 0.867437
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0418025	valid's score: 0.83025
# [1000]	valid's l2: 0.0400265	valid's score: 0.833287
# [1500]	valid's l2: 0.0395135	valid's score: 0.834181
# Early stopping, best iteration is:
# [1409]	valid's l2: 0.0394855	valid's score: 0.83423
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0196121	valid's score: 0.87716
# [1000]	valid's l2: 0.0186101	valid's score: 0.879957
# [1500]	valid's l2: 0.0183026	valid's score: 0.880835
# Early stopping, best iteration is:
# [1446]	valid's l2: 0.018299	valid's score: 0.880845
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0446712	valid's score: 0.825521
# Early stopping, best iteration is:
# [889]	valid's l2: 0.0436865	valid's score: 0.827121
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0563661	valid's score: 0.808136
# Early stopping, best iteration is:
# [529]	valid's l2: 0.0562918	valid's score: 0.808238
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [280]	valid's l2: 0.0156319	valid's score: 0.888867
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [245]	valid's l2: 0.0116518	valid's score: 0.902573
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0340991	valid's score: 0.844125
# [1000]	valid's l2: 0.0322549	valid's score: 0.847747
# Early stopping, best iteration is:
# [1134]	valid's l2: 0.0321323	valid's score: 0.847993
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [370]	valid's l2: 0.0184428	valid's score: 0.880433
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [330]	valid's l2: 0.0550079	valid's score: 0.81002
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0432819	valid's score: 0.827785
# Early stopping, best iteration is:
# [468]	valid's l2: 0.0431072	valid's score: 0.828073
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0382519	valid's score: 0.836413
# [1000]	valid's l2: 0.0363538	valid's score: 0.839866
# [1500]	valid's l2: 0.0347861	valid's score: 0.842808
# [2000]	valid's l2: 0.0344013	valid's score: 0.843543
# Early stopping, best iteration is:
# [2296]	valid's l2: 0.0342725	valid's score: 0.84379
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0219112	valid's score: 0.871062
# Early stopping, best iteration is:
# [649]	valid's l2: 0.0216152	valid's score: 0.871823
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0164216	valid's score: 0.886409
# Early stopping, best iteration is:
# [442]	valid's l2: 0.0163576	valid's score: 0.886606
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.10084	valid's score: 0.758983
# [1000]	valid's l2: 0.0942303	valid's score: 0.765129
# [1500]	valid's l2: 0.0919124	valid's score: 0.767359
# Early stopping, best iteration is:
# [1793]	valid's l2: 0.0914288	valid's score: 0.76783
# Training until validation scores don't improve for 100 rounds.
# [500]	valid's l2: 0.0171346	valid's score: 0.884252
# Early stopping, best iteration is:
# [514]	valid's l2: 0.0170248	valid's score: 0.884581
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [282]	valid's l2: 0.0189124	valid's score: 0.879104
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [166]	valid's l2: 0.0226147	valid's score: 0.869277

# %%
print('local cv:',1/(1+np.sqrt(mean_squared_error(train['y'],np.mean(val_preds,axis=0)))))
# Out:
# local cv: 0.852215878345

# %%
pd.Series(model.feature_importance(importance_type='gain'),
          index=model.feature_name()).sort_values(ascending=False).head(10)
# Out:
# P_A        177202.330046
# log_P_A    144375.902258
# I_A         52886.129968
# P_C         23843.209814
# P_avg       19786.504029
# log_P_C     11110.939180
# I_C          4295.495398
# log_P_B      3999.880512
# log_I_C      3550.889470
# log_I_A      2343.036369
# dtype: float64

# %%
test['ans'] = np.mean(test_predicts, axis=0)
# Out:
# /Users/yuanhao/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test[['ID','ans']].to_csv('../result/0727-8534-bagging.csv',header=False, index=False)
